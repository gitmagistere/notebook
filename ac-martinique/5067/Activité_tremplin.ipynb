# %% [markdown]
# # Étude d'un tremplin de ski

# %% [markdown]
# ##Présentation du travail ##
# Ce travail vise à réaliser une activité initialement destinée à des élèves de seconde. Cette activité est présentée comme un <i>notebook</i> c'est-à-dire un document qui contient à la fois du texte pour exprimer des consignes ou des explications et du code Python exécutable. Par exemple la cellule ci-dessous contient du code:

# %%
def f(x):
  return x**2
[f(x) for x in range(11)]
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ##Exercice d'introduction##
# Dans la cellule ci-dessous, créer un programme qui affiche les cubes des 15 premiers entiers.
# Conseils:
#  - On pourra bien sûr copier et coller le code ci-dessus
#  - Exécuter le code pour valider votre réponse

# %%
#A vous de jouer !

# %% [markdown]
# ## Présentation de l'activité
# - **Niveau de classe :**
# Initialement classe de seconde générale et technologique mais le contenu a été modifié pour s'adapter à des étudiants de master MEEF
# - **Références au programme :**
#  - Seconde: *Étudier l’alignement de trois points dans le plan*.
#  - Seconde: *Déterminer une équation de droite passant par deux points donnés*.
#  - Seconde: *Algorithme de calcul approché de longueur d’une portion de courbe représentative de fonction*.
# - **Prérequis :**
#  * Équations de droites.
#  * Images et antécédents.
#  * Distances entre deux points.
# - **Description** L'étude de la structure d'un tremplin de saut à ski permet de réexploiter les notions d'alignement, d'équations droites et de fonction. On étudie la forme du tremplin, la hauteur des supports et la longueur de la piste.

# %% [markdown]
# ## Situation
# Une station de sports d'hiver souhaite
# construire un tremplin de saut à ski dont la structure est en acier.
# Le profil de la piste est représenté dans un plan rapporté à un repère
# orthonormal $(O, I,J)$. L’unité est le mètre.
# La piste d’envol du tremplin est constituée de 2 parties :
#
# • une partie représentée par un segment $[AB]$.
#
# • une partie représentée par un arc de parabole  $\overset{\frown}{BD}$
#  . Il faut qu’il y ait raccordement au point $B$.
# ![tremplin.png](data:image/png;base64,...)

# %% [markdown]
# ## Étude de la partie $[AB]$
# La première partie est portée par un support rectiligne passant par le point $A$ de coordonnées $(0,15)$ et le point $C$ de coordonnées $(24,0)$.
# Le raccordement entre les deux parties doit se faire au point $B$ de coordonnées $(16,5)$.

# %% [markdown]
# ### Alignement de trois points
# **Compléter** la fonction `alignement` pour qu'elle vérifie si trois points de coordonnées entières sont alignés. Elle prend les coordonnées entières des trois points en paramètres et renvoie un booléen.

# %%
def alignement(x1,y1,x2,y2,x3,y3):
    #A compléter
    return 
alignement(0,15,24,0,16,5)

# %% [markdown]
# ## Hauteurs des poteaux
# La première partie du tremplin est supportée par des poteaux placés tous les quatre mètres (abscisses : 4, 8 et 12).
# On souhaite déterminer la hauteur de ses poteaux.

# %% [markdown]
# ### Équation de droite
#  - **Compléter** la fonction  `equation` pour qu'elle donne les coefficients $a$ et $b$ de l'équation réduite $y=ax+b$ d'une droite passant par deux points d'abscisses différentes. Elle prend les coordonnées des deux points en paramètres et renvoie les valeurs de $a$ et $b$.
#  - **Faire afficher** les valeurs de $a$ et $b$ en fin de script.
#  - **Tester la fonction**  `equation` afin d'obtenir le coefficient directeur et l'ordonnée à l'origine de la droite $(AB)$.

# %%
def equation(xA,yA,xB,yB):
    assert xB!=xA, "il faut donner deux points d'abscisses distinctes"
    #A compléter
    return a,b

# %% [markdown]
# <div class="alert alert-warning">
#
# **Remarque:**
# </div>
#
# L'utilisation de `assert` permet de vérifier que les abscisses des deux points sont distinctes.
#
# Dans le cas contraire, `assert` interrompt le déroulement de l'exécution et affiche le message `"il faut donner deux points d'abscisses distinctes"`.
#
#
# <div class="alert alert-info">

# %% [markdown]
# ### Image par une fonction affine
#  - **Compléter** la fonction ci-dessous qui détermine l'image d'un réel $x$ par une fonction affine d'équation $ g(x)=ax+b$. Elle prend les valeurs de $a$ et $b$ et celle de $x$ en paramètres et renvoie l'image de $x$.
#  - **Utiliser** cette fonction pour déterminer la hauteur des trois poteaux.

# %%
def fonctionAffine(a,b,x):
    pass
    #A compléter

# %% [markdown]
# ## Longueur de la piste sur la partie $[AB]$.
# Afin de placer le revêtement sur la piste, on souhaite connaître sa longueur totale.
#  - **Créer** une fonction qui calcule la longueur d'un segment $[M_1 M_2]$ dans  un repère orthonormal  $(O,I,J)$. Elle prend les coordonnées des points $M_1(x_1,y_1)$ et $M_2(x_2,y_2)$ en paramètres et renvoie la longueur de la piste en unités de longueur.
#
#  - **Tester** ce programme pour calculer la distance $AB$.

# %%
import math
#A compléter

# %% [markdown]
# ## Étude de la partie $\overset{\frown}{BD}$
# La deuxième partie du tremplin est un arc de parabole d'équation $f(x)=0{,}03x^2 - 1{,}56x + 22{,}28$.
# L'abscisse du point $D$ est égale à $28$.

# %% [markdown]
# ### Coordonnées de D
#  - **Créer** une fonction $f$ qui calcule l'image d'un réel $x$ par la fonction $f$.
#  - **Tester** cette fonction pour déterminer l'ordonnée de $D$.

# %%
#Coder la fonction 'f' et le test ici

# %% [markdown]
# ### Longueur de l'arc $\overset{\frown}{BD}$.
# Pour calculer la longueur totale du revêtement, on souhaite évaluer également la longueur de la deuxième partie de la piste.
#
# Pour cela, on divise l'intervalle $[16;28]$ en $n$ intervalles de longueur $\frac{(28-16)}{n}=\frac{12}{n}$.
# On place alors les points $A_0$,$A_1$,$A_2$,...$A_n$ de la courbe d'abscisses respectives :
#
# $16$; $16+\frac{12}{n}$; $16+2\times\frac{12}{n}$;...; $28$.
#
# Pour calculer une valeur approchée de notre portion de courbe, il suffit alors de faire la somme des longueurs des segments $[A_i;A_{i+1}]$.
#
#  - **Compléter** la fonction ci-dessous pour qu'elle réalise l'algorithme présenté
#  - **Tester** cette fonction pour $n=10$, $borneInf=16$ et $borneSup=28$.

# %%
def LongueurArc(n,borneInf,borneSup):
    longueurTotale=0
    x1=borneInf
    pas=....
    x2=x1+pas
    for i in range(n):
        ....
    return longueurTotale

# %% [markdown]
# ### Animation susceptible d'être présentée aux élèves
# Les programmes suivants sont à destination de l'enseignant et permettent d'illustrer en classe la convergence de la longueur approchée.
#  - Tester ce programme
#  - Modifier le programme pour ajouter une étiquette (label) à l'axe des abscisses
#  - Modifier l'intervalle des ordonnées des points affichés dans le deuxième graphique.

# %%
# %matplotlib inline
import matplotlib.animation
from IPython.display import HTML
import matplotlib.pyplot as plt

#Points
def listePoints(n,borneInf,borneSup):
    pas=(borneSup-borneInf)/n
    listeAbscisses=[borneInf+i*pas for i in range(n+1)]
    listeOrdonnees=[f(x) for x in listeAbscisses]
    return listeAbscisses,listeOrdonnees
def longueurApprochee(n,borneInf,borneSup):
    liste=[]
    for i in range(1,n):
        liste.append(LongueurArc(i,borneInf,borneSup))
    return liste

#cte
N = 15

lX,lY=listePoints(1000,16,28)
fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(15, 6))
ax1.plot(lX,lY,'r--')
ax1.set_title('Courbe approchée',color="#1e7fcb",fontsize=14)
ax2.set_title('Approximation longueur',color="#1e7fcb",fontsize=14)
courbeSegments, = ax1.plot([],[],'.-',color="#1e7fcb")
courbeConvergence, = ax2.plot([],[],color="#1e7fcb")
ax2.set_xlim(( 0, N))
ax2.set_ylabel("Longueur de la ligne brisée")
ax2.set_ylim((0, 13))


def init():
    global courbeSegments,courbeConvergence
    courbeSegments.set_data([], [])
    courbeConvergence.set_data([], [])
    return (courbeSegments,) 

def animate(i):
    global courbeSegments,courbeConvergence
    lx,ly=listePoints(i+1,16,28)
    courbeSegments.set_data(lx,ly)
    valeurs = longueurApprochee(i+2,16,28)
    courbeConvergence.set_data(range(1,i+2),valeurs)
    ax1.set_title('Courbe approchée - nombre de Segments:{}'.format(i+1))
    ax2.set_title('Approximation longueur $\simeq${:.3f}'.format(valeurs[-1]))
    return (courbeSegments,)
  

plt.close ()
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=N,init_func=init,blit=False,interval=750)
# l'un ou l'autre
HTML(ani.to_jshtml())
#HTML(ani.to_html5_video())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img93bbc93cb23643b3b4233fbeec52e3d0">
#   <div class="anim-controls">
#     <input id="_anim_slider93bbc93cb23643b3b4233fbeec52e3d0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim93bbc93cb23643b3b4233fbeec52e3d0.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim93bbc93cb23643b3b4233fbeec52e3d0.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select93bbc93cb23643b3b4233fbeec52e3d0" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_93bbc93cb23643b3b4233fbeec52e3d0"
#              >
#       <label for="_anim_radio1_93bbc93cb23643b3b4233fbeec52e3d0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_93bbc93cb23643b3b4233fbeec52e3d0"
#              checked>
#       <label for="_anim_radio2_93bbc93cb23643b3b4233fbeec52e3d0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_93bbc93cb23643b3b4233fbeec52e3d0"
#              >
#       <label for="_anim_radio3_93bbc93cb23643b3b4233fbeec52e3d0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img93bbc93cb23643b3b4233fbeec52e3d0";
#     var slider_id = "_anim_slider93bbc93cb23643b3b4233fbeec52e3d0";
#     var loop_select_id = "_anim_loop_select93bbc93cb23643b3b4233fbeec52e3d0";
#     var frames = new Array(15);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nOzdeViU5f7H8fewCyKIIKuKCq7gSlmn\
# 0pK0UhM1y2xxSfNki+3WqdNpL6uT5a/T5lJppqXmUq4px6NZWbnviooKiMi+b7P8/hhBSVSUZRj9\
# vK6LK5ln5pnvzBDPw+e57/trsFgsFkRERERERERE7JiDrQsQEREREREREakuBRwiIiIiIiIiYvcU\
# cIiIiIiIiIiI3VPAISIiIiIiIiJ2TwGHiIiIiIiIiNg9BRwiIiIiIiIiYvcUcIiIiIiIiIiI3VPA\
# ISIiIiIiIiJ2TwGHiIiIiIiIiNg9BRwiIiIiIiIiYvcUcIiIiIiIiIiI3VPAISIiIiIiIiJ2TwGH\
# iIiIiIiIiNg9BRwiIiIiIiIiYvcUcIiIiIiIiIiI3VPAISIiIiIiIiJ2TwGHiIiIiIiIiNg9BRwi\
# IiIiIiIiYvcUcIiIiIiIiIiI3V

# %% [markdown]
# ##Pour finir:##
# Ecrire un programme qui permet de calculer des valeurs approchées d'un quart de disque et qui illustre ces approximations à la manière de ce qui a été fait précédemment.
