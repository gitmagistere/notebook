# %% [markdown]
# LOUER A ORLEANS   ![image.png](attachment:image.png)
#
#      En  2019, un couple a emménagé dans un pavillon à Orléans. Le montant annuel de leur loyer était
#      alors de 10 800 €.
#     L’évolution de l’IRL peut être modélisée par une augmentation moyenne de 1,27 % par an.
#     On considère que cette tendance observée depuis 1998 va se maintenir ainsi durant les années à venir.
#
#     Le couple envisage de faire des économies durant cette location afin d’acheter un pavillon. Il programme cela dans une dizaine d’années.
#
#
#
# Problématique :
#
# Selon cette modélisation, combien le couple aura-t-il dépensé durant ces 10 années ?
#
#
#
# Source : https://www.insee.fr/fr/statistiques/4478590#graphique-irl-g1-fr

# %% [markdown]
# Complétez le programme suivant permettant de répondre à la problématique.

# %%
def somme(u1,q,n):
    L=[...for k in range(n)]
    return(round(...,2))
