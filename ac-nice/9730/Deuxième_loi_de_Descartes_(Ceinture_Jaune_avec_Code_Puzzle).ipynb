# %% [markdown]
# <div style="padding:5px; border: 0.1rem solid #BBB;border-left: 6px solid #855CBD;border-radius:6px;background-color:white;">
#
#  <div style="float:right; width:150px; padding-top:20px; padding-left:10px;">
# <img src="https://nuage02.apps.education.fr/index.php/apps/files_sharing/publicpreview/RYdGEdzYxSq8HZg?file=/&fileId=55228649&x=2560&y=1440&a=true">
# </div>
#
# <div style="float:left; width:150px">
# <img src="https://nuage02.apps.education.fr/index.php/apps/files_sharing/publicpreview/C4N9SksFxZmJSdT?file=/&fileId=55318112&x=1920&y=1080&a=true" width="90px">
# </div>
#     <div style="padding-top:15px;padding-bottom:15px;text-align:center;">
#         Groupe Numérique Disciplinaire
#         <h2 style="color:#855CBD">Activité 2 - Deuxième loi de Snell-Descartes (avec CodePuzzle)</h2>
#     </div>
# </div>

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A6FA8;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-bullseye" aria-hidden="true"></i>&nbsp;Introduction</div>
#     <div style="padding:10px;">
#     Bonjour à tous !
#
# Si vous êtes ici c'est que vous avez choisi la difficulté "ceinture jaune". Vous disposez donc du code dans le désordre qu'il faut remettre en ordre. Pour cela, exécutez la cellule 1 ci-dessous et déplacez les lignes. Une fois validé copiez le code, collez le dans la cellule 2 et exécutez-le !
# </div>
# </div>

# %% [markdown]
# ### Cellule 1

# %%
from IPython.display import IFrame
IFrame('https://www.codepuzzle.io/IPCZSE', width='100%', height=600)

# %% [markdown]
# ### Cellule 2

# %% [markdown]
# ### Cellule 3

# %%
#Modélisation
droite = np.polyfit(sini1,sini2,1)
coeff_dir=droite[0]
print("Le coefficient directeur de la droite est ", coeff_dir)

plt.xlabel('sini1')
plt.ylabel('sini2')
plt.title('Vérification de la seconde loi de Descartes')
plt.plot(sini1,sini2,'b+', label='Valeurs expérimentales')
plt.plot(sini1,coeff_dir*sini1,'r--', label='Modélisation')
plt.legend()
plt.show()
