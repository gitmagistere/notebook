# %% [markdown]
# <div style="padding:5px; border-radius:6px;background-color:lightsalmon;">
# <figure style="float:right">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2023/03-20/8-35-34/logo%20Nice%20acade%CC%81mie.jpg>
# </figure>
#     <center>
#         <h1><u><center><span style=font-family:Chalkduster>L'as des trois points !</u></font> </h1>
#     </center>
# </div>

# %% [markdown]
# Saisir vos NOMS et Prénoms:

# %% [markdown]
# <div class ="alert alert-success"style="border-left: 10px solid #3c763d;border-radius:2px;">
# <font color='Green'><h3>I. Valeurs expérimentales </font></h3>
# </div>

# %% [markdown]
# <div style="background-color: ivory;color:black;
# padding:20px;">
# <i class="fa fa-hand-o-right" aria-hidden="true"></i> __À vous de faire:__
# <ul>
#     <li> Copier les listes de valeurs récupérées depuis le logiciel Chronophys.</li>
#     <li> <span style="color: red"> cliquer sur le bouton <i class="fa fa-step-forward" aria-hidden="true"></i> Executer la cellule pour actualiser votre saisie</span>.</li>
# </ul>
# </div>

# %% [markdown]
# <div class ="alert alert-success"style="border-left: 10px solid #3c763d;border-radius:2px;">
# <font color='Green'><h3> II. Tracé de graphique </font></h3>
# </div>

# %% [markdown]
# <div style="background-color: ivory;color:black;padding:20px;">
# <i class="fa fa-hand-o-right" aria-hidden="true"></i> __À vous de faire:__
# <ul>
#     <li> Compléter le script python ci-dessous de façon à tracer le graphique représentant le ... en fonction ...:</li>
#        <ul>
#            <li> Choisir les listes contenant les valeurs des abscisses et des ordonnées grâce à la ligne plt.plot(abscisses,ordonnees,'r+') </li>
#            <li> Légender les abscisses grâce à la ligne plt.xlabel("......") </li>
#            <li> Légender les ordonnées grâce à la ligne plt.ylabel("......") </li>
#            <li> Mettre un titre grâce à la ligne plt.title("......") </li>
#        </ul>
#     <li> <span style="color:red";> Cliquer ensuite sur le bouton <i class="fa fa-step-forward" aria-hidden="true"></i>  Executer la cellule pour actualiser votre saisie</span>. </li>
# </ul>
# <br>
#
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(1,figsize=(10,10))
plt.clf()
plt.xlim(0,1.1*max(liste_x))
plt.ylim(0,1.1*max(liste_y))
plt.title('Titre du graphique')#legende titre graphique
plt.xlabel('axe des abcisses')#legende axe abscisses
plt.ylabel('axe des ordonnées')#legende axe ordonnées
plt.plot(abscisse,ordonnée, 'x')#trajectoire du ballon
plt.grid()#quadrillage
plt.show()#Affichage du graphique

# %% [markdown]
# <div class ="alert alert-success"style="border-left: 10px solid #3c763d;border-radius:2px;">
# <font color='Green'><h3> III. Modélisation </font></h3>
# </div>

# %% [markdown]
# <div style="background-color: ivory;color:black;padding:20px;">
# <i class="fa fa-hand-o-right" aria-hidden="true"></i> __À vous de faire:__
# <ul>
#     <li> <i class="fa fa-step-forward" aria-hidden="true"></i>  Exécuter le script suivant.</li>
#     </ul>
# </div>

# %%
coeff_y=np.polyfit(liste_x,liste_y,2)
print('y_{modelisation}=',coeff_y[0],'x^2 +',coeff_y[1], 'x +',coeff_y[2])

x=np.linspace(0,7,200)
#liste de modélisation de y(t):y_m
y_m=[]
y_m=[coeff_y[2]+coeff_y[1]*i+coeff_y[0]*i**2 for i in x]


plt.figure('modelisation',figsize=(10,7))# Création d'une figure 
plt.clf()#nettoyage de la figure
plt.grid(which='both')
plt.ylabel("y(m)")
plt.xlabel("x(m)")
plt.xlim(0,max(x))
plt.ylim(0,6)
plt.title(f"Modélisation de la trajectoire")
plt.plot(liste_x,liste_y,'b+',markersize=10,label="y(x)")
plt.plot(x,y_m,'y-',label='modélisation de y(x)')
plt.legend()
plt.show()
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
# NameError: name 'np' is not defined
# Error:

# %% [markdown]
# <p style="padding:5px;background-color:#5989e8;border:1px solid black;border-radius:20px;font-weight:bold;color:white;font-size:2em;padding:15px;"> Fin du TP</b>

# %% [markdown]
# <div class="alert alert-info" style="solid #31708f;"><b>AVANT DE TERMINER</b><br>
# - Sauvegarder votre travail. <br>
# - Rendre votre travail
# </div>
