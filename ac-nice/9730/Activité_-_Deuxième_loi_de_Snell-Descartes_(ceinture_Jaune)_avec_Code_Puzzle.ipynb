# %% [markdown]
# <div style="padding:5px; border-radius:6px;background-color:lightsalmon;">
# <figure style="float:left">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-23/9-43-31/Ceinture%20jaune-2.jpg>
# </figure>
# <figure style="float:right">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2023/03-12/20-34-55/logo%20Nice%20acad%C3%A9mie.jpg>
# </figure>
#     <center>
#         <h1><u><center><span style=font-family:Chalkduster><u>Activité : "Deuxième loi de Snell-Descartes" </u></font> </h1>
#     </center>
# </div>

# %% [markdown]
# <div class ="alert alert-info">
# <h2><font color='blue'><font style=font-family:Papyrus>Introduction </font></span></h2>
# Bonjour à tous !
# Si vous êtes ici c'est que vous avez choisi la difficulté "ceinture jaune". Vous disposez donc du code dans le désordre et il faut le remettre en ordre. Pour cela exécutez la cellule dessous. Déplacez les lignes puis une fois validé copiez le et exécutez-le !
# </div>

# %%
from IPython.display import IFrame
IFrame('https://www.codepuzzle.io/IP6JN7', width='100%', height=600)

# %%
#Modélisation
droite=linregress(sini2,sini1)
coeff_dir=droite.slope
print("Le coefficient directeur de la droite est ", coeff_dir)
