# %% [markdown]
# <div style="padding:5px; border: 0.1rem solid #BBB;border-left: 6px solid #855CBD;border-radius:6px;background-color:white;">
#
# <figure style="float:right; width:150px">
# <img src="data:image/jpeg;base64,...">
# </figure>
#     <center style="padding-top:15px;padding-bottom:15px;">
#         Groupe Numérique Disciplinaire
#         <h2 style="color:#855CBD">TP1 - Vitesse du son (deuxième partie)</h2>
#     </center>
# </div>

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A6FA8;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-bullseye" aria-hidden="true"></i>&nbsp;Introduction</div>
#     <div style="padding:10px;">Bonjour à tous !
#
# Aujourd'hui dans cette deuxième partie de TP on utilise un <font style="font-weight:bold">**notebook**</font> qui est un cahier électronique pouvant rassembler des images, du texte et des formules. Deux types de cellules sont présentes dans un notebook :
# <ul>
#     <li>des cellules contenant du texte,</li>
#     <li>et des cellules exécutables contenant du code.</li>
# </ul>
#
# Vous allez donc à présent exploiter les différentes mesures obtenues dans la première partie du TP avec l'application numérique Phyphox et découvrir l'utilisation du langage de programmation python pas à pas. N'oubliez pas d'exécuter les cellules au fur et à mesure et de compléter par la même occasion votre fiche <font style="font-weight:bold">"Trousse à outils"</font> ainsi que celle concernant <font style="font-weight:bold"> "la gestion des erreurs" </font>.</div>
# </div>

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A9460;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-arrow-right" aria-hidden="true"></i>
# &nbsp;Importation des bibliothèques nécessaires</div>
#     <div style="padding:10px;">
#     Une bibliothèque Python permet de rajouter des fonctionnalités au langage de base. Tout d'abord, j'importe donc la bibliothèque nécessaire au tracé des graphiques intitulée "<code>matplotlib</code>" grâce à la ligne de code d'en dessous. N'oubliez pas d'éxécutez la cellule pour que l'importation ait lieu !
#     </div>
# </div>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A9460;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-arrow-right" aria-hidden="true"></i>
#        &nbsp;Création des variables <code>deltatsur2</code> et <code>d</code></div>
#     <div style="padding:10px;">
#         Afin de rentrer les valeurs des variables <code>deltatsur2</code> et <code>d</code>, nous allons créer ce que l'on appelle des listes. Ce sont des structures de données qui contiennent une série de valeurs.
#     </div>
# </div>

# %% [markdown]
# <span style="color:#F55C45"><i class="fa fa-exclamation-triangle" aria-hidden="true"></i></span> N'éxécutez la cellule qu'une fois les données complétées !

# %%
deltatsur2=[]# à compléter par vous 
d=[]# à compléter par vous

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A9460;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-arrow-right" aria-hidden="true"></i>
#        &nbsp;Tracé du graphique</div>
# </div>

# %%
plt.plot(deltatsur2, d, "b+") # La fonction plot(x,y) trace la courbe y=f(x) à partir des listes x et y .

# %%
plt.show() # affichage du graphe.

# %% [markdown]
# <i class="fa fa-pencil" aria-hidden="true"></i> <b>Quelles sont les indications manquantes sur le graphe ? Nous allons les rajouter ensemble :</b>

# %% [markdown]
# <i class="fa fa-pencil" aria-hidden="true"></i> <b>Au vue de la courbe obtenue quel type de relation existe t-il entre d et deltatsur2 ? </b>

# %% [markdown]
# <i class="fa fa-pencil" aria-hidden="true"></i> <b>Que représente le coefficient directeur de la droite obtenue ?</b>

# %% [markdown]
# <div style="border: 0.1rem solid #BBB;border-left: 5px solid #4A9460;border-radius:6px;background-color:white;">
#    <div style="background-color:#EEE; padding-left:10px; font-size:16px; font-weight:bold; padding-top:3px; padding-bottom:3px;"><i class="fa fa-arrow-right" aria-hidden="true"></i>
#        &nbsp;Modélisation de la droite</div>
#           <div style="padding:10px;">
#         Nous allons à présent modéliser la droite obtenue afin d'avoir son coefficient directeur à l'aide de la fonction "<code>linregress()</code>" du module scipy.
#         </div>
# </div>

# %%
from scipy.stats import linregress 
droite=linregress(deltatsur2,d)
coeff_dir=droite.slope
print("Le coefficient directeur de la droite est ", coeff_dir)

# %% [markdown]
# <i class="fa fa-pencil" aria-hidden="true"></i> <b>Quelle est la valeur de la vitesse du son obtenue ? Vous porterez un regard critique sur votre valeur.</b>
