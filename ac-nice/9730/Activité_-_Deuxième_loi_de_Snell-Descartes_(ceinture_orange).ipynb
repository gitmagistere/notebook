# %% [markdown]
# <div style="padding:5px; border-radius:6px;background-color:lightsalmon;">
#  <figure style="float:left">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-25/11-31-46/Ceinture%20orange.jpg>
# </figure>
# <figure style="float:right">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2023/03-12/20-44-42/logo%20Nice%20acad%C3%A9mie.jpg>
# </figure>
# </figure>
#     <center>
#        <h1><u><center><span style=font-family:Chalkduster>Activité : "Deuxième loi de Snell-Descartes" </u></font> </h1>
#     </center>
# </div>

# %% [markdown]
# <div class = "alert  alert-info">
#     <h2><font color='blue'><font style=font-family:Papyrus>Introduction </font></span></h2>
#
# Bonjour à tous !
# Si vous êtes ici c'est que vous avez choisi la difficulté "ceinture orange". Vous disposez donc du code dans le désordre où des erreurs se sont glissées. A vous de jouer !
# </div>

# %%
plt.show()

# %%
plt.xlabel('sini1')
plt.ylabel('sini2')
plt.title('Vérification de la seconde loi de Descartes')

# %%
i1=[0,10,20,30,40,50;60]
i2=[0,8,15,23,30,36]

# %%
plt.plot(,,'b+')

# %%
import numpy as np
import 
from scipy.stats import linregress

# %%
#Modélisation
droite=linregress(sini2,sini1)
coeff_dir=droite.slope
print("Le coefficient directeur de la droite est ", coeff_dir)

# %%
sini1 = np.sin(np.radians(i1))
print (sini1)
sini2= np.sin(np.radians(i2))
print (sini2)
