# %% [markdown]
# # boucle For

# %% [markdown]
# ### activité n°0

# %% [markdown]
# Reprenons le petit exemple, exécutez le et observez ce qui se produit

# %%
for i in range(1,5):
    print(i)
print("fin de boucle")

# %% [markdown]
# Vous remarquerez que la boucle s'est itérée 4 fois, et pas 5...Normal puisque la vérification se fait au niveau de la ligne du for...et donc quand i=5 on sort directement de celle-ci.

# %% [markdown]
# ### activité n°1

# %% [markdown]
# Ecrire un programme qui va permettre d'écrire 10 fois "bonjour"

# %% [markdown]
# ### activité n°2

# %% [markdown]
# écrire un programme qui va calculer 10 fois de suite le résultat de la fonction mathématique $2i^2+5$ et l'afficher pour chaque itération, $i$ étant la valeur de l'index d'itération.
