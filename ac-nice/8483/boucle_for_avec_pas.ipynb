# %% [markdown]
# # boucle For...avec pas modifiable

# %% [markdown]
# ### activité n°3

# %% [markdown]
# Reprenons ce petit exemple, exécutez le code ci-après et observez ce qui se produit...changez le pas pour vérifier que cela fonctionne bien (vous pouvez chnager les bornes également).

# %%
for i in range(1,30,3):
    print(i)
print("fin de boucle")
