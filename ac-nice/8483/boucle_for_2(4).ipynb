# %% [markdown]
# # Boucle for

# %% [markdown]
# ### activité n° 2

# %%
from random import *

n=randint(1,10)
print(n)

# %% [markdown]
# Reprendre le code de ce programme et faire en sorte qu'il ne charge pas tous les modules de la bibliothèque random mais juste le module randint.

# %% [markdown]
# Afin de vérifier si cela a fonctionné correctement, testez l'appel d'un autre module, par exemple random().
#
# <span style="color:red">Attention : </span>pensez pour cela à redémarrer le noyau sans quoi la mémoire contiendra les modules appelés au préalable !

# %% [markdown]
# On rappelle qu'en python il est possible de <b>commenter</b> un programme au fur et à mesure de son écriture.
#
# Pour cela, on utilise les htags <span style="color:green">#</span> ce qui permet au compilateur de comprendre que ce qui suit sur la même ligne est un commentaire.
#
# Exemple:

# %%
from random import * #on importe en mémoire tous les modules de la bilbliothèque random.

n=randint(1,10)
print(n)

# %% [markdown]
# Commentez la suite du programme que nous utilisons actuellement...
