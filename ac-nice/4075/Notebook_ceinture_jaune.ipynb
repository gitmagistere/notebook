# %% [markdown]
# # <font color='red'><u>Activité : "Deuxième loi de Snell-Descartes" </u></font>
# <div class="pull-right">
# <center>
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2022/05-23/9-43-31/Ceinture%20jaune-2.jpg>
# </center>
# </div>

# %% [markdown]
# ## <font color='blue'><span style=font-family:Papyrus>Introduction </font></span>
# Bonjour à tous !
# Si vous êtes ici c'est que vous avez choisi la difficulté "ceinture jaune". Vous disposez donc du code dans le désordre et il faut le remettre en ordre !

# %%
plt.show()

# %%
i1=[0,10,20,30,40,50,60]
i2=[0,8,15,23,30,36,42]

# %%
plt.plot(sini2,sini1,'b+')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#Modélisation
droite=linregress(sini2,sini1)
coeff_dir=droite.slope
print("Le coefficient directeur de la droite est ", coeff_dir)

# %%
sini1 = np.sin(np.radians(i1))
print (sini1)
sini2= np.sin(np.radians(i2))
print (sini2)
