# %%
m=[0,]#stockage des valeurs expérimentales de la masse
V=[0,]#stockage des valeurs expérimentales du volume

# %%
plt.figure("Première représentation graphique")#création de la figure
plt.plot(m,V)#Tracé de la courbe
plt.show()#Affichage de la courbe
# Out:
# Traceback (most recent call last):
#   File "<input>", line 2, in <module>
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt
