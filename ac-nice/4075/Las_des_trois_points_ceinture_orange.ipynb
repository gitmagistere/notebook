# %% [markdown]
# <div style="padding:5px; border-radius:6px;background-color:lightsalmon;">
#     <figure style="float:left">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2022/06-30/10-15-11/basket.jpg>
# </figure>
#     <figure style="float:right">
# <img src=https://capytale2.ac-paris.fr/web/sites/default/files/2022/07-20/13-38-12/Ceinture%20orange.jpg>
# </figure>
#     <h1><u><center><span style=font-family:Chalkduster>TP : "L'as des trois points !"</span> </h1></u> </div>

# %% [markdown]
# <div class="alert alert-info">
#     <h2><font color='blue'><span style=font-family:Papyrus>Introduction </font></span></h2>
#
# Bonjour à tous !
# Voici donc le notebook qui accompagne votre Tp.
#
# Le pointage des différentes coordonnées du ballon lors de ce tir a déjà été réalisé par votre professeur.Vous avez choisi la ceinture orange. Vous disposez donc du code dans le désordre où quelques erreurs se sont glissées. A vous de le remettre en ordre !
#
# N'oubliez pas de commenter votre programme et de compléter par la même occasion si nécessaire votre fiche <font color='red'>"Trousse à outils"</font> ainsi que celle concernant <font color='red'> "la gestion des Erreurs" </font>.
# ****************
# </div>

# %%
plt.show

# %%
y=3.49,3.69,3.88,3.96,4.16,4.32,4.45,4.56,4.69,4.82,4.89,4.98,5.08,5.13,5.21,5.24,5.29,5.27,5.25,5.16,5.08,4.92
,4.79,4.61,4.45,4.19,3.93,3.54
t=[0,0.03,0.06,0.10,0.13,0.16,0.20,0.23,0.27,0.30,0.33,0.37,0.40,0.43,0.47,0.50,0.53,0.57,0.60,0.63,0.67,0.70,0.73
   ,0.77,0.80,0.83,0.87,0.90]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(, ,'g+')

# %%
plt.xlabel('')
plt.ylabel('')
plt.title('')
