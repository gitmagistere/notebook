# %% [markdown]
# # Un notebook jupyter
#
# Pour tester les fonctionnalités.
#
# Avec markdown, on peut mettre du texte en *italique*, en **gras** voire en ***gras italique*** !
# et même des portions de code : `def carre(x)`
#
# Les mathématiques sont au rendez-vous : $f:x\mapsto \frac{x^2}{2}$
#
# La fonction  ci-dessus est d'ailleurs programmée ci dessous :

# %%
def f(x):
    return x**3

f(5)
# Out:
# 125

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 500) # 500 valeurs entre -10 et 10
plt.plot(x, f(x), color="blue", linewidth=1.5, linestyle="-")
