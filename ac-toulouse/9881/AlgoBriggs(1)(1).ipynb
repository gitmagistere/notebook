# %% [markdown]
# ### Une valeur approchée de $\log(3)$
# Compléter le code ci-dessous.

# %%
from math import sqrt
def logarithme(h):
    a=1
    b=10
    logA=...
    logB=...
    while b-3>h : 
        if sqrt(a*b)<3 : 
            a=sqrt(a*b)
            logA=...
        else : 
            b=sqrt(a*b)
            logB=...
    return logB

# %% [markdown]
# Tester alors votre fonction. Pour "information", un valeur approchée de $\log(3)$ à $10^{-3}$ près est 0,477.

# %% [markdown]
# ### Aller plus loin
#
# Modifier la fonction ci-dessus et écrire une fonction en langage Python ayant pour paramètres $x$ et $h$ avec $x \in [1;10]$ qui renvoie une approximation de $\log(x)$ avec une précision $h$.

# %%
def logarithme(h):
    a=1
    b=10
    logA=...
    logB=...

# %% [markdown]
# Tester alors votre fonction. Pour "information", un valeur approchée de $\log(3)$ à $10^{-3}$ près est 0,477.
