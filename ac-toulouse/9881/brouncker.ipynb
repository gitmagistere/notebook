# %% [markdown]
# A vous de jouer et coder l'algorithme de Brouncker.

# %%
def brouncker(n):
    S=0
    for k in range(...):
        S=...
    return S

# %% [markdown]
# En utilisant la fonction précédente, écrire la fonction approximation_ln2 qui admet comme paramètre un réel h>0 et qui retourne la plus petite valeur n pour laquelle brouncker(n) est une approximation de ln 2 à h près.

# %%
def approximation_ln2(h):
