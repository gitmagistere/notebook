# %% [markdown]
# ## I. Fonctions

# %% [markdown]
# ### Exercice 1

# %% [markdown]
# Le programme ci-dessous définit la fonction périmètre qui à la largeur et à la longueur d'un rectangle renvoit son périmètre.

# %%
def pr(l,L):
    P=2*(l+L)
    return(P)

# %% [markdown]
# Dans la cellule de code ci-dessous, écrire une instruction renvoyant le périmètre d'un rectangle de largeur 3 et de longueur 10.

# %% [markdown]
# ### Exercice 2

# %% [markdown]
# Ecrire dans la cellule de code ci-dessous une fonction renvoyant l'aire d'un disque.

# %% [markdown]
# ## II. Instructions conditionnelles

# %% [markdown]
# ### Exercice 1

# %% [markdown]
# On considère la fonction affine par morceau écrite ci-dessous.
#
# $f(x) = \begin{cases}
# -x +4 \text{ si }x \leq -1 \\
# 3x -1 \text{ si }-1 < x \leq 5 \\
# x + 2 \text{ si }x > 5
# \end{cases} $
#
# Compléter la fonction Python ci-dessous pour qu'elle renvoie la valeur de $f(x)$ lorsqu'on l'utilise avec l'argument $x$.

# %%
def f(x):
    if ... 
        y = ...
    elif ... 
        y = ...
    else:
        y = ...
    return y

# %% [markdown]
# ### Exercice 2

# %%
def mystere(n):
    if n%2==0:
        y=n/2
    else:
        y = 3*n+1
    return y

# %% [markdown]
# 1. Que renvoie la fonction suivante s'il on utilise la valeur $n = 22$ ?

# %% [markdown]
# 2. Que renvoie la fonction si l'on utilise la valeur $n = 3$ ?

# %% [markdown]
# 3. Que teste l'instruction **if n%2 == 0** ?

# %% [markdown]
# ## III. Boucles

# %% [markdown]
# ### Exercice 1

# %% [markdown]
# On considère la suite $(u_n)$ dont chaque terme est défini par la fonction Python suivante :

# %%
def u(n):
    u=150
    for k in range(1,n+1) :
      u=2/3*u
    return(u)

# %% [markdown]
# **1.** Préciser le premier terme $u_0$ et la raison.

# %% [markdown]
# **2.** Ecrire ci-dessous l'instruction Python qui permettent de calculer $u_{20}$

# %% [markdown]
# **3.** Donner la formule explicite de $(u_n)$

# %% [markdown]
# **4** Modifier ci-dessous la fonction Python précédente pour qu'elle renvoie le plus entier naturel $n$ tel que $u_n<0,01$.

# %% [markdown]
# ## IV. La légende du jeu d'échecs

# %% [markdown]
# *Une légende dit que, pour le remercier de l’invention du jeu d’échecs, l’empereur Shiram promit à son inventeur Sissa le cadeau de son choix. Sissa lui demanda alors :*
#
# *« Déposez un grain de riz sur la 1ère case, puis le double sur la 2ème case, et ainsi de suite en doublant à chaque fois le nombre de grains. »*
#
# *Dans un kilogramme de riz, il y a environ 40 000 grains de riz.
# Actuellement, la production mondiale annuelle est d’environ 450 millions de tonnes de riz.*
#
# *On veut déterminer au bout de la combientième case le nombre de grains de riz déposés sur l'échiquier aura dépassé la production mondiale annuelle actuelle de riz.*

# %% [markdown]
# **1.** On rappelle que dans un kilogramme de riz, il y a environ 40 000 grains de riz.
# Actuellement, la production mondiale annuelle est d’environ 450 millions de tonnes de riz.
# Calculer le nombre de grains de riz produits annuellement dans le monde.

# %% [markdown]
# **2.** Compléter le programme ci-dessous pour qu'il renvoie la case à partir de laquelle le nombre de grains de riz déposés sur l'échiquier aura dépassé la production annuelle mondiale.

# %%
n=1
u=1
s=1
while s<:
  n=
  u=
  s=
print()
