# %%
from random import*

def gain():
  d=randint(1,6)
  if d==6:
    return 120
  elif d==1 or d==2:
    return -60
  else:
    return 20

# %%
total=0

for i in range(1000000):
  total=total+gain()
print(total/1000000)
# Out:
# 10.01828
