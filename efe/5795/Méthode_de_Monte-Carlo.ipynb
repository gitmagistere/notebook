# %% [markdown]
# ---
# # **Méthode de Monte-Carlo**
#
#
# ---

# %% [markdown]
# Cette activité a pour but la découverte d'une méthode algorithmique basée sur une approche fréquentiste permettant d'obtenir l'aire d'une surface délimitée par une courbe dont l'équation est connue.
#
# Nous commencerons par utiliser cette méthode dans le cadre du quart de disque pour la modifier dans le calcul de la quadrature de la parabole.
#
#
#
#
#
#
#
# ---
# # **Présentation de la méthode**
#
#
# ---
#
#
#
#
# On place au hasard un grand nombre N de points dans un carré OABC de côté 1.
#
#
# On note n le nombre de points dans le quart de disque de centre O et à l’intérieur de OABC.
# D’après la loi des grands nombres, plus N est grand, plus le rapport
# n/N
# est proche de la probabilité qu’un point du carré appartienne
# au quart de disque.
# 1. Combien devrait valoir cette probabilité? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 2. Comment peut-on en déduire une approximation de pi ? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# 3. Donner une condition sur les coordonnées x et y pour que M(x; y) soit dans le quart de disque :
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# ---
# # **Mise en oeuvre sur Python**
#
#
# ---
#
# On veut tirer des nombres au hasard, quelle bibliothèque de Python doit-on utiliser ?
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# Quelle(s) instruction(s) doit-on mettre au début du programme? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
#
#
# On veut visualiser la simulation faite ci-dessus, quelle bibliothèque de Python doit-on utiliser ? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# Quelle instruction doit-on mettre au début du programme? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# 1. Créons une liste vide qui va stocker les abscisses de nos points, on la note X.
# 2. De même, créons la liste Y.
# 3. Créons enfin une liste colormap qui servira à la couleur des points dans le 6).
# 4. Créons une fonction MC(N) qui calcule la fréquence des points dans le quart de disque

# %%
from .......
from .......

X=[]           #on créé la liste X
........       # on crée la liste Y
......         # on crée la liste colormap

def MC(N):
  n=0
  for k in range(N):
    ...............   #on tire une abscisse x de M au hasard entre 0 et 1
    ...............   # on tire une ordonnée de y de M au hasard entre 0 et 1
    ...............   # on ajoute x à X
    ...............   # on ajoute y à Y
    if......................... : # on regarde si M est dans le quart de disque 
        .......................  # on incrémente le compteur
  ...............   # on calcule la fréquence
  return f*4


MC(1000)

# %% [markdown]
# 5. Puis ajoutons maintenant cette fonction pour afficher une fenêtre graphique avec les points :

# %%
def grapheMC (N):
  print(MC(N))
  plt.axis (xmin = .... , xmax = .... , ymin =.... , ymax = ...)
  plt.scatter(X,Y)
  plt.show()

MC(1000)

# %% [markdown]
# 6. Cette image ne nous apporte pas grand chose des tirages bien qu'elle montre ce qu'il se passe. Il reste à modifier la fonction MC(N) avec plt.scatter(X,Y,c=colormap) pour que les points soient coloriés en (1,0,0) s’ils sont dans
# le quart de disque et (0,0,1) sinon.

# %%
from .......
from ......


X=[]           #on créé la liste X
........       # on crée la liste Y
......         # on crée la liste colormap

def MC(N):
  n=0
  for k in range(N):
    ...............   #on tire une abscisse x de M au hasard entre 0 et 1
    ...............   # on tire une ordonnée de y de M au hasard entre 0 et 1
    ...............   # on ajoute x à X
    ...............   # on ajoute y à Y
    if......................... : # on regarde si M est dans le quart de disque 
        .......................  # on incrémente le compteur
        ......................   # on ajoute le tuple (1,0,0) à colormap
    else :
        ......................   # on ajoute le tuple (0,0,1) à colormap    
    ...............   # on calcule la fréquence
    return f

def grapheMC(N):
  print(MC(N))
  plt.axis (xmin = .... , xmax = .... , ymin =.... , ymax = ...)
  plt.scatter(X,Y,c=colormap)
  plt.show()

grapheMC(2000)

# %% [markdown]
# ---
# # **Quadrature de la parabole**
#
#
# ---

# %% [markdown]
# En s’inspirant de la méthode utilisée ci-dessus, on cherche à programmer une fonction aire qui prend en argument le nombre de
# points à générer et qui renvoie une approximation de l’aire du domaine délimité par la parabole d’équation $y = x^2$, l’axe des
# abscisses et les droites d’équation $x = 0$ et $x = 1$.
#
# 1. Démontrer que cette aire est comprise entre $\dfrac14$ et $\dfrac12$.
#
# ![quad.PNG](data:image/png;base64,...)
#
# 2. Programmer l’algorithme sous Python :
