# %% [markdown]
# # Définir une fonction

# %% [markdown]
# ## 1. Apprendre en étudiant un exemple.

# %% [markdown]
# **a. La fonction cube**
# Dans la cellule ci-dessous est définie la fonction cube qui retourne le cube d'un nombre réel noté x.
# *Exécuter la cellule ci-dessous en appuyant sur la touche **►** dans la barre d'outils en haut de l'écran.*
# Exécuter permet à l'ordinateur d'enregistrer chronologiquement votre travail

# %%
def cube(x):
    return(x**3)

# %% [markdown]
# Dans la cellule ci-dessous, on applique cette fonction cube en précisant la valeur du paramètre x.
# *Exécuter la cellule ci-dessous.*

# %%
cube(2)

# %% [markdown]
# Dans les cellules suivantes, appliquer la fonction cube en -2 ; 150 ; 1/2 et 0.1 :

# %% [markdown]
# Que pensez-vous du dernier résultat ? Compléter ci-dessous :

# %% [raw]
# De tête, le cube de 0,1 vaut
# Le résultat donné par Python est donc

# %% [markdown]
# **Retenir de l'exemple ci-dessus comment :**
# - Définir une fonction.
# - Lister des paramètres.
# - Retourner un résultat.

# %% [markdown]
# **b. La fonction carrée**

# %% [markdown]
# Dans la cellule suivante, définir la fonction carrée en respectant bien la syntaxe de l'exemple 1.
# Retenir que l'**indentation** *(ou alinéa)* créée par **:** *(deux-points)* indique le début de la définition.
# La fin de l'indentation marque la fin de la définition.

# %% [markdown]
# Tester la fonction carrée en donnant les carrés de -3 ; 1/4 et 0.2.

# %% [markdown]
# ## 2. Applications :

# %% [markdown]
# Définir, exécuter puis appliquer les fonctions suivantes donnant :
# *Compléter les cellules*

# %% [markdown]
# **a. Le périmètre d'un carré.**

# %%
def pc(c):

# %% [markdown]
# *Quel est le périmètre d'un carré de côté 3 ?*

# %% [markdown]
# **b. Le périmètre d'un rectangle.**

# %%
def pr(l,L):

# %% [markdown]
# *Donner un exemple :*

# %% [markdown]
# **c. L'aire d'un rectangle.**

# %% [markdown]
# *Donner un exemple :*

# %% [markdown]
# **d. Le périmètre d'un cercle de rayon r.**

# %%
from math import *             # On importe le module math pour définir le nombre pi.

def circonférence

# %% [markdown]
# *Donner un exemple :*
# Un exemple bien choisi est toujours celui que l'on parvient à faire soi-même de tête afin de vérfier la cohérence des résultats.

# %% [markdown]
# **e. L'aire d'un disque de rayon r.**

# %%
def

# %%
ad()

# %% [markdown]
# ## 3. Exercices :

# %% [markdown]
# **a. Le montant d’une facture lors d’une vente par correspondance dépend :**
# - de la quantité q
# - du prix unitaire p
# - des frais d’envoi f
#
# *Définir la fonction facture calculant ce montant.*

# %% [markdown]
# *Combien coûte 10 livres à 8€ avec 5€ de frais d'envoi ?*

# %% [markdown]
# **b. Définir la fonction tension calculant la tension aux bornes d’une résistance traversée par un courant électrique.**

# %% [markdown]
# *Donner la tension électrique aux bornes d'une résistance de 250Ω  traversée par un courant de 12mA.*

# %% [markdown]
# **c. Votre IMC (indice de masse corporel) dépend :**
# - de votre poids P (en kg)
# - de votre taille T (en m).
#
# **Définir la fonction IMC permettant son calcul IMC=P/T²**

# %% [markdown]
# *Donner votre IMC.*
