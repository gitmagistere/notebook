# %% [raw]
# Noms et Prénoms

# %% [markdown]
# Une **instruction conditionnelle** permet d'effectuer des choix dans un programme en fonction de la valeur vraie ou fausse d'une condition :
# - si la condition est vraie, on effectue des instructions ;
# - si la condition est fausse, on effecture d'autres instructions.

# %% [markdown]
# En **langage naturel**, la syntaxe d'une instruction conditionnelle est la suivante :
#
# ![if](https://zupimages.net/up/23/14/o8y4.png)

# %% [markdown]
# En **langage Python**, la syntaxe dépend du nombre de conditions.
# ![syntif](https://zupimages.net/up/23/14/gyhc.png)

# %% [markdown]
# **Remarques**
# - Le mot-clé "Alors" n'existe pas en langage Python. C'est l'**indentation**, c'est-à-dire le décalage automatique du retour à la ligne vers la droite qui le remplace.
# - **elif** est la contraction de **else if**.
# - Pour tester l'égalité de deux valeurs en langage Python, on peut utiliser le signe "==".

# %% [markdown]
# ## Exercice 1

# %% [markdown]
# Ecrire en langage Python les instructions conditionnelles ci-dessous écrites en langage naturel.

# %% [raw]
# Si t est égale à 0 alors
#     y <- t + 1

# %% [markdown]
# ## Exercice 2

# %% [markdown]
# On considère le programme suivant.

# %%
x = ...
if 0<x<1:
    y = 3*x
elif x>=1:
    y=4*x
else:
    y = 5*x

# %% [markdown]
# Quelle est la valeur de $y$ lorsqu'on prend $x = -1$

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# Compléter la fonction **Exercice _3**, d'argument $x$, qui renvoie le double de $x$ si $x$ est positif et le triple de $x$ si $x$ est négatif ou nul.

# %%
def Exercice_3(x):
    if ... :
        y = ...
    else:
        y=...
    return y

# %% [markdown]
# ## Exercice 4
#
# Une machine automatique de la Poste indique le tarif à payer selon le poids $x$ du courrier, exprimé en grammes.
#
# La fonction Python suivante constitue le programme de la machine et renvoie le prix à payer **P** (exprimé en euros).

# %%
def prix(x):
    if 0<x<=20:
        P = 0.67
    elif 20<x<=50:
        P=0.85
    elif 50<x<=100:
        P=1.25
    return P

# %% [markdown]
# 1. Quel est l'argument de cette fonction ?

# %% [markdown]
# 2. Quel est le prix affiché si le client poste un courrier de :
#
# a) 72 grammes ?

# %% [markdown]
# b) 18 grammes ?

# %% [markdown]
# 3. Modifier la fonction pour qu'elle renvoie un prix à payer de 2,50€ pour un courrier qui pèse plus de 100 grammes.

# %% [markdown]
# ## Exercice 5
#
# On considère la fonction affine par morceau écrite ci-dessous.
#
# $f(x) = \begin{cases}
# -x +4 \text{ si }x \leq -1 \\
# 3x -1 \text{ si }-1 < x \leq 5 \\
# x + 2 \text{ si }x > 5
# \end{cases} $
#
# Compléter la fonction Python ci-dessous pour qu'elle renvoie la valeur de $f(x)$ lorsqu'on l'utilise avec l'argument $x$.

# %%
def f(x):
    if ... 
        y = ...
    elif ... 
        y = ...
    else:
        y = ...
    return y

# %% [markdown]
# ## Exercice 6

# %%
def mystere(n):
    if n%2==0:
        y=n/2
    else:
        y = 3*n+1
    return y

# %% [markdown]
# 1. Que renvoie la fonction suivante s'il on utilise la valeur $n = 22$ ?

# %% [markdown]
# 2. Que renvoie la fonction si l'on utilise la valeur $n = 3$ ?

# %% [markdown]
# 3. Que teste l'instruction **if n%2 == 0** ?

# %% [markdown]
# ## Exercice 7
#
# Ecrire une fonction Python, nommée **examen**, d'argument un nombre entier $n$ compris entre 0 et 20 et qui renvoie la phrase "Candidat reçu" si $10 \leq n \leq 20$.
