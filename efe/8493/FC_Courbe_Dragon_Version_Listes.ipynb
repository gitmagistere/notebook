# %% [markdown]
# <div align="center"><h1>La courbe du dragon</h1></div>
#
#
# ## 1 - Définition
# #### La figure ci-contre représente la courbe de Heighway, nom d’un des physiciens de la NASA l’ayant étudiée en premier. Nommée aussi courbe du dragon pour sa ressemblance avec cet animal, c’est un objet mathématique passionnant par ses différentes propriétés.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2 - L'agorithme de construction
#
# #### L'algorithme de construction de cette courbe fractale  est très simple :
#
#
# #### - plier une bande de papier en 2, replier à nouveau en 2 autant de fois que souhaitées
# #### - déplier en prenant soin d'ouvrir chaque pli à angle droit.
#
# ![Courbe_dragon.png](attachment:Courbe_dragon.png)
#
# #### Le résultat obtenu réserve alors quelques surprises : la bande de papier ainsi dépliée rentre parfois en contact avec elle même mais sans jamais "traverser", quelque soit le nombre de pliages les courbes se ressemblent toutes ; un dragon avec de l'imagination...

# %% [markdown]
# #### a) A l'aide des feuilles cartonnées,  réaliser la courbe du dragon, jusqu'au rang 3.
# #### b) Peut-on envisager de réaliser la courbe du dragon au rang 4, 5, 10 ?

# %% [markdown]
# ## 3 - Programmation de l'agorithme par la méthode des L-Système
#
# #### Un L-Système est une méthode de réécriture de mots. Plus précisément, on définit une liste initiale puis une règle de réécriture à appliquer à chaque élément de la liste.
#
# #### a) Pourquoi la méthode du L-Système est bien adaptée pour modéliser cette fractale  ?
# #### b) En considérant "D" pour une rotation à droite et "G" pour une rotation à gauche, écrire les listes correspondantes aux trois premières itérations.
# #### c) En déduire une régle de réécriture compatible avec notre courbe du dragon
# #### On notre ```dragon(n)``` la liste obtenue après ```n``` réécritures
# #### d) Déterminer la liste de caractères ```dragon(2)``` obtenue après 2 réécritures successives de la liste initiale "D".
# #### e) Vérifier que ```dragon(3)``` = ["D","D","G","D","D","G","G","D","D","D","G","G","D","G","G"]
# #### f) Compléter le code de la fonction ```miroir(liste)``` ci-dessous qui renvoie la liste miroir otenue en parcourant la variable ```liste``` de droite à gauche et remplaçant "D" par "G"et vice-versa :
#
# ```python
# def miroir(liste):
#     liste_miroir = []
#     .........
#     return liste_miroir
# ```
# Exemple :
# ```python
#
# >>> miroir()
# >>> ['D','G','G']
# ```

# %%
#travail à faire
# Out:
# ['D', 'G', 'G']

# %% [markdown]
# #### g) Ecrire une fonction ```dragon(n)``` qui renvoie la liste obtenue après ```n``` réécritures de la liste intiale L = ["D"].
#
# Exemple :
#
# ```python
# >>> dragon(3)
# >>> ['D','D','G','D','D','G','G','D','D','D','G','G','D','G','G']
# ```

# %%
#travail à faire
# Out:
# ['D']

# %% [markdown]
# ### Le module graphique ```turtle``` de Python permet de piloter "un crayon" afin de tracer des figures géométriques. Ecrire une fonction ```trace_dragon(n,pas)``` qui réalise le tracé de la courbe du dragon en ```n``` itérations. Le ```pas``` correspond à la longueur de base du tracé.

# %%
#travail à faire 
from turtle import*
speed(0)
color('blue')

def trace_dragon(n,pas):
    L = dragon(n)
    forward(pas)
    pass


trace_dragon(10,4)
done()
