# %% [markdown]
# <div align="center"><h1>Les listes</h1></div>
#
#
# ## 1 - Définition
#
# ### Les listes font partie de ce qu'on appelle les *données composites* . Elles permettent de regrouper de manière structurée des ensembles de valeurs. On les appelle *listes* en Python, ou bien *tableaux* de manière plus générale.
#
#
# **Notation :** dans une liste, les éléments sont séparés par des **virgules**, et l'ensemble est délimité par des **crochets**.

# %%
ma_premiere_liste = [1, "ok", True]

# %% [markdown]
# ### Même si cela n'a ici un grand intérêt, les éléments d'une liste peuvent donc être de types différents : ici, nous avons successivement un entier (`int`), une chaine de caractères (`str`), et un booléen (`bool`).

# %% [markdown]
#  ## 2 - Accès aux éléments d'une liste
#  #### On accède à un élément d'une liste en mettant entre crochets l'indice de l'élémént.
#
#
#  ![image.png](attachment:image.png)
#
#  <div align="center"><h6>Famille des EEMCP2 Mathématiques du Liban</h6></div>

# %% [markdown]
#  ### a) Pour la liste famille ci-dessous, quelle instruction doit-on écrire pour renvoyer ```"Bart"``` ?

# %%
#Compléter ce script pour acceder au premier élément de cette liste
famille = ["Bart", "Lisa", "Maggie"]

# %% [markdown]
# ### b) Un indice qui dépasse la valeur  `longueur de la liste -1` provoquera une erreur `list index out of range`. Que renvoie l'instruction ```famille[3]``` ?

# %%
#Vérifier votre réponse ici

# %% [markdown]
# ### c) Il est par contre possible d'utiliser des indices **négatifs**. Que va renvoyer l'instruction ```famille[-1]``` ?

# %%
#Vérifier votre réponse ici

# %% [markdown]
# ### d) En utilisant un indice négatif, quelle instruction peut-on utiliser pour accéder à ```Bart``` ?

# %%
#Vérifier votre réponse ici

# %% [markdown]
# ## 3 - Longueur d'une liste
# ### La longueur d'une liste sera donnée par l'instruction `len()`

# %%
#Tester cette instruction pour la liste famille

# %% [markdown]
# ### Attention : le dernier élément d'une liste a donc l'indice `len(liste)-1`.  Tester le script ci-dessous pour vous en convaincre !!!

# %%
from tutor import tutor

liste = [1,2,3,4,5,6,7,8,9]
longueur_liste = len(liste)
premier_index = 0
dernier_index = len(liste)-1
tutor()

# %% [markdown]
# ## 4 -  Parcours des éléments d'une liste

# %% [markdown]
# ### Pour parcourir les éléments d'une liste, nous avons à notre disposition deux stratégies :
#
# #### - en travaillant sur les indices/index
# ```python
# for k in range(len(famille)):
#     print(famille[k])
# ```
# #### - en travaillant sur les éléments
#
# ```python
# for elt in famille :
#     print(elt)
# ```

# %%
#Tester la première méthode

# %%
#Tester la première méthode

# %% [markdown]
# ## 5 -  Les éléments d'une liste sont MODIFIABLES.
#
# ### On dit que les listes sont des objets **mutables**.
#
# #### La photo de la famille des EEMCP2 de mathématiques du Liban dans la partie 2 a été piraté, voici ci-dessous le bon cliché :
#
# ![image.png](attachment:image.png)
#
# ### a) Proposer un script pour modifier les 3 valeurs de la liste ```famille```, pour obtenir :
#
# #### ```famille = [ "Matthieu", "Sébastien", "Vincent"]```

# %%
#Travail à faire

# %% [markdown]
# ### b) Quelle instruction peut-on utiliser pour vérifier le contenu de la liste ```famille```

# %%
#Travail à faire

# %% [markdown]
# ## 6 -  Ajout d'un élement à une liste
#
# ### Pour ajouter un élément à une liste on utilise la méthode  ```append()```. Attention, elle ajoute un élément à la fin de la liste.
#
# #### Exemple : Le script suivant permet d'ajouter 2024 à la liste ```année_bissextile``` qui est composée de ```[2012,2016,2020]```
#
# ```python
# année_bissextile = [2012,2016,2020]
# année_bissextile.append(2024)
# année_bissextile
# ```
#
# ### a) Tester l'exemple ci-dessus :

# %%
#Travail à faire

# %% [markdown]
# ### b) Proposer une instruction sur la liste ```famille``` pour mettre à jour la famille des EEMCP2.

# %%
#Travail à faire

# %% [markdown]
# ## 7 - Liste vide
#
# ### Très souvent, la méthode `append()` ci-dessus est utilisée à partir d'une liste vide `[]`, à laquelle on rajoute peu à peu des éléments.

# %% [markdown]
# ###  Exemple :
#
# #### On cherche à filtre la liste ```prix``` ci-dessous pour n'en garder que les éléments Inférieurs à 20.
#
# #### On donne le script à completer ci-desssous :
#
# ```python
#
# prix = [45, 12, 15, 20, 18, 19, 23, 17, 12, 18]
#
#
# def filtrage(liste_initiale):
#     liste_finale = ..............
#     for elt in ..................:
#         if elt................ 20:
#             liste_finale.append(.........)
#
# filtrage(prix)
# ````

# %%
#travail à faire

# %% [markdown]
# ## 8 - Suppression d'un élément d'une liste
#
# ### Pour supprimer un élément à une liste on peut utiliser la méthode  ```remove()```.
#
# #### Exemple 1 : La liste ```famille``` a été modifié par un pirate informatique localisée à Hanoï. La voici lors du dernier appel :
#
# ```python
# >>> famille
# >>>["Matthieu", "Sébastien", "Vincent", "Nicolas", "Christophe"]
# ```
#
# ### a) Proposer une instruction pour éliminer l'intrus

# %%
#travail à compléter 
famille = ["Matthieu", "Sébastien", "Vincent", "Nicolas", "Christophe"]
......
famille

# %% [markdown]
# ### Attention, la méthode ```remove()``` va supprimer le premier élément de la liste rencontré (ce qui est problématique s'il y en a plusieurs).
#
# #### Exemple 2 : On considère le script suivant :
#
# ```python
# maliste = [8, 4, 2, 4, 7]
# maliste.remove(4)
# ```
# ### b) Quelle liste obtient-on après ces deux instructions ?

# %%
#travail à faire

# %% [markdown]
# ###  Pour supprimer un élément d'une liste on peut utiliser la fonction ```del()``` :
#
# #### La fonction ```del()``` permet de supprimer un élément en précisant  son indice.
#
# #### Exemple 4 : On donne le script suivant :
#
# ```
# maliste = [8, 4, 2, 5, 7]
# del maliste[3]
# maliste
# ```
#
# ### c) Que devient ```maliste``` ?

# %%
#travail à faire

# %% [markdown]
# ## 9 - Constructions de liste

# %% [markdown]
# ### a)  Construction d'une liste d'éléments identiques
#
# ### Tester l'instruction ci-dessous :

# %%
#Instruction à tester
p = [0]*12

# %% [markdown]
# #### Cette instruction est très utile pour initialiser des listes de taille donnée.

# %% [markdown]
# ### b) Construction d'une liste dite par compréhension
#
# ### Tester l'instruction suivante :

# %%
nombres = [k for k in range(10)]

# %% [markdown]
# ### -  Il est bien sûr possible d'agir sur le paramètre.
#
# ### Tester l'instruction suivante :

# %%
carres_parfaits = [k**2 for k in range(10)]

# %% [markdown]
# ### - Plus subtil, on peut filtrer "à la volée" les éléments pour n'en garder que certains.
#
# ### Tester l'instruction suivante :

# %%
c = [n for n in carres_parfaits if n % 3 == 0]

# %% [markdown]
# ## 10 - Exercices :
#
# ### Exercice 1 : Construire une fonction ```meme_place(L1,L2)``` qui renvoie la valeur de l'élément (et sa position) qui est exactement à la même place dans la liste `L1` et dans la liste `L2` (les deux listes ont la même taille).
#
# ```python
# def meme_place(liste1, liste2):
#     L =...........
#     for i in range(........):
#         if liste1[i] == ..............:
#             ...........................
#     return L
# ```

# %%
#Travail à faire
def meme_place(liste1, liste2):
  none

L1 = [8468, 4560, 3941, 3328, 7, 9910, 9208, 8400, 6502, 1076, 5921, 6720, 948, 9561, 7391, 7745, 9007, 9707, 4370, 9636, 5265, 2638, 8919, 7814, 5142, 1060, 6971, 4065, 4629, 4490, 2480, 9180, 5623, 6600, 1764, 9846, 7605, 8271, 4681, 2818, 832, 5280, 3170, 8965, 4332, 3198, 9454, 2025, 2373, 4067]
L2 = [9093, 2559, 9664, 8075, 4525, 5847, 67, 8932, 5049, 5241, 5886, 1393, 9413, 8872, 2560, 4636, 9004, 7586, 1461, 350, 2627, 2187, 7778, 8933, 351, 7097, 356, 4110, 1393, 4864, 1088, 3904, 5623, 8040, 7273, 1114, 4394, 4108, 7123, 8001, 5715, 7215, 7460, 5829, 9513, 1256, 4052, 1585, 1608, 3941]

# %% [markdown]
# ### Exercice 2 : Créer en une ligne une liste `p` qui contient tous les éléments positifs de `m`.

# %%
#Travail à faire 
m = [-3, -6, 4, 7, -2, 1, -3, 5]

# %% [markdown]
# ### Exercice 3  : Construire une fonction ```max_liste(liste)``` qui renvoie le maximun d'une liste

# %%
#Travail à faire

# %% [markdown]
# ### Exercice 4 : Construire une fonction ```min_liste(liste)``` qui renvoie le minimum d'une liste

# %%
#Travail à faire

# %% [markdown]
# ### Exercice 5 : Construire une fonction ```slice_first(liste)``` qui renvoie la liste sans le 1er élément

# %%
#Travail à faire

# %% [markdown]
# ### Exercice 6 :Construire une fonction ```slice_last(liste)``` qui renvoie la liste sans le dernier élément

# %%
#Travail à faire
