# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99";>
# <div style="color:#ffffff;">
#
# # Squelette Notebook
# </div>
#
# <span class="badge" style="color:#ffffff; background-color: #ee5555 ; font-size: 25px;"> SNT/NSI</span>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Une cellule à modifier pour écrire un contenu de présentation/de cadrage
# </div>

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Une activité</h2>
#
# L'utilisation d'un notebook facilite l'apprentissage, mais sachez que la plupart du temps on utilise un *éditeur de code* pour écrire et exécuter des programmes Python.
#
# C’est un logiciel qui se décompose généralement en deux fenêtres :
#
# - la **fenêtre d’édition** (à gauche dans la capture d'écran ci-dessous) dans laquelle on écrit le programme dans le langage Python
# - et la **console** (à droite dans la capture d'écran) dans laquelle peuvent notamment s’afficher les valeurs des variables souhaitées.
#
# ![Basrhon_Console.png](attachment:Basrhon_Console.png)
#
#
# Il existe énormément d'éditeur et nous utiliserons pour cette séance un éditeur en ligne appelé **BASTHON** (qui signifie **B**ac **À** **S**able Py**thon**) qui ne nécessite pas d’installation (vous pourrez donc l’utiliser chez vous rien qu’avec une connexion Internet). On peut également installer une version offline.
#
# Voici un lien permettant d'accéder à Basthon : [https://console.basthon.fr/](https://console.basthon.fr/).
#
# 🐍 **Consigne** : Cliquez sur le lien ci-dessus pour ouvrir l'éditeur de code puis recopiez dans la fenêtre d'édition (celle de gauche) le programme de l'activité précédente. Vous exécuterez ensuite le programme en cliquant sur le bouton "Exécuter" et observerez bien que c'est dans la console (fenêtre de droite) que s'affiche la valeur de la variable `a`.

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exemple 1
#
# </div>

# %%
from IPython.display import IFrame
IFrame(src="https://www.codepuzzle.io/PNHVL", width=800, height=500)
# Out:
# <iframe src="https://www.codepuzzle.io/PNHVL" allowfullscreen="" width="800" height="500" frameborder="0"></iframe>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exemple 2
#
# </div>

# %%
from IPython.display import IFrame
IFrame(src="https://www.codepuzzle.io/PRP4F", width=900, height=400)
# Out:
# <iframe src="https://www.codepuzzle.io/PRP4F" allowfullscreen="" width="900" height="400" frameborder="0"></iframe>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exemple 3
#
# </div>

# %%
from IPython.display import IFrame
IFrame(src="https://www.codepuzzle.io/DEHW2", width=800, height=500)
# Out:
# <iframe src="https://www.codepuzzle.io/DEHW2" allowfullscreen="" width="800" height="500" frameborder="0"></iframe>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exemple 4
#
# </div>

# %%
from IPython.display import IFrame
IFrame(src="https://www.codepuzzle.io/DMH3R", width=900, height=500)
# Out:
# <iframe src="https://www.codepuzzle.io/DMH3R" allowfullscreen="" width="900" height="500" frameborder="0"></iframe>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Intégrer une image 1
# <img src="https://aefe-liban.fr/wp-content/uploads/2022/09/Pascale-Louvrier-1.jpg" alt="capture d'écran d'une console Basthon" width="200">
#
# </div>

# %% [markdown]
# # Intégrer un pdf

# %%
from IPython.display import IFrame
IFrame(src="https://www.sujetdebac.fr/annales-pdf/2023/spe-numerique-informatique-2023-metropole-2-sujet-officiel.pdf", width=900, height=500)
# Out:
# <iframe src="https://www.sujetdebac.fr/annales-pdf/2023/spe-numerique-informatique-2023-metropole-2-sujet-officiel.pdf" allowfullscreen="" width="900" height="500" frameborder="0"></iframe>

# %%
from IPython.display import HTML
HTML("""<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/7b3QupZc08Y" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/7b3QupZc08Y" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# from IPython.display import HTML
# HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/JiokX41_2nw?si=2THSNs37b5LiOuQx" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>""")

# %%
from IPython.display import HTML
HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/JiokX41_2nw?si=2THSNs37b5LiOuQx" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/JiokX41_2nw?si=2THSNs37b5LiOuQx" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
