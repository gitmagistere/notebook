# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99";>
# <div style="color:#ffffff;">
#
# # La librairie Microblocks
# </div>
#
# <span class="badge" style="color:#ffffff; background-color: #ee5555 ; font-size: 25px;"> SNT/NSI</span>
#
#
# Une activité de Nathalie Maïer
# Inspirée par une activité utilisant un sensehat de Stéphane Renouf
#
# *Les activités partagées sur <a href="https://capytale2.ac-paris.fr/web/accueil">**Capytale**</a> sont sous licence <a href="https://creativecommons.org/licenses/by-sa/3.0/fr/">Creative Commons</a>.*

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ### Exécuter la cellule ci-dessous pour pouvoir utiliser l'objet `BlockGrid`

# %%
from ipythonblocks import BlockGrid

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ### Exécuter la cellule ci-dessous

# %%
R = 200
G = 0
B = 0
BlockGrid(7, 8, block_size=30, fill=(R, G, B))
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksd09acd99-4e48-4fea-b48f-e2cc70196fcb td {border: 1px solid white;}</style><table id="blocksd09acd99-4e48-4fea-b48f-e2cc70196fcb" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (200, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(200,
# ...

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ### Que se passe-t-il ?

# %% [markdown]
# **Votre réponse :** *double cliquer dans la cellule pour écrire votre réponse*

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Dans le code ci-dessous, changer les valeurs contenues dans les variables  `R`, `G` et `B` pour spécifier qu'on veut une intensité maximale (255) pour le rouge, et une intensité minimale (0) pour le vert et le bleu.
# Puis exécuter de nouveau le code.

# %%
R = 0
G = 0
B = 0
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# En s'aidant de la figure sur l'addition des couleurs, modifier à nouveau les valeurs des variables `R`, `G` et `B` pour obtenir les couleurs jaune, magenta puis cyan.

# %%
# pour le jaune 
R = 0
G = 0
B = 0
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %%
# pour le mangenta
R = 0
G = 0
B = 0
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %%
# pour le cyan
R = 0
G = 0
B = 0
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Sachant que l'intensité de chaque couleur est donnée par un nombre compris entre 0 et 255, quel est le nombre de couleurs qu'on peut obtenir par le principe du mélange des couleurs ?

# %% [markdown]
# **Votre réponse :** *double cliquer dans la cellule pour écrire votre réponse*

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Faire des essais en remplaçant `R`, `G` et `B` par des valeurs numériques.

# %%
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Choisir la même valeur pour `R`, `G` et `B` (sauf 0 et 255). Quelle couleur obtient-on ?

# %%
BlockGrid(8, 8, block_size=30, fill=(R, G, B))

# %% [markdown]
# **Votre réponse :** *double cliquer dans la cellule pour écrire votre réponse*

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Les pixels
# Un pixel est un petit élément d'une surface de visualisation dans une image numérique.  Chaque pixel de votre écran est constitué de trois sous-pixels (rouge, vert et bleu).
# C'est de cette façon que fonctionnent tous les écrans d'ordinateur et de smartphone.
# Ainsi une image est composée de petits points appelés pixel. Un pixel est composé de trois parties : une partie rouge, une partie verte et une partie bleue.
# À chaque pixel, on associe donc 3 couleurs : le rouge, le vert et le bleu. On parle du canal rouge, du canal vert et du canal bleu d'un pixel
# (on parle de système RVB ou RGB en anglais). La valeur de l'intensité lumineuse associée à chaque canal de chaque pixel d'une image est comprise entre 0 et 255 (on a 256 valeurs possibles).
# On codera donc un pixel à l'aide d'un triplet de valeurs, la première valeur donnant l'intensité du canal rouge, la deuxième valeur donnant l'intensité du canal vert et la troisième valeur
# donnant l'intensité du canal bleu.
#
# ## Exercice
# 1. Pour pouvoir agir sur les carrés de la grille, il faut lui donner un nom : nous choisirons la variable `grille` pour y stocker une grille noire de dimension 8$\times$8.
# Pour afficher le contenu de la variable `grille`, il suffira d'écrire `grille` dans une cellule du notebook puis de l'exécuter.
# Exécuter les cellules ci-dessous

# %%
grille = BlockGrid(8, 1, block_size=40, fill = (220,220,220))

# %%
grille
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks4786665b-3bcb-424d-871d-43d670a7290a td {border: 1px solid white;}</style><table id="blocks4786665b-3bcb-424d-871d-43d670a7290a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 1]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 2]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 3]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 4]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 5]&#10;Color: (220, 220, 220)" style="width: 4
# ...

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# On accède à un carré de la grille en précisant ses coordonnées dans la grille entre crochets.
# La première coordonnée est le numéro de ligne, la seconde le numéro de colonne.
# **Attention :** les numéros débutent à 0 et ici finissent à 7 puisque notre grille est de dimension 8$\times$8.
# Pour modifier la couleur d'un carré, on utilise la commande : `grille[ligne, colonne] = (R, G, B)`
#
# Compléter le code ci-dessous pour modifier la couleur du carré de coordonnées `(0, 0)` en rouge.

# %%
# version modifiée
grille[0, 0] = (250, 0, 0)
grille  # pour voir
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks94aa9af1-21a4-452f-b6cc-9eaf336a1fff td {border: 1px solid white;}</style><table id="blocks94aa9af1-21a4-452f-b6cc-9eaf336a1fff" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (250, 0, 0)" style="width: 40px; height: 40px;background-color: rgb(250, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 2]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 3]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 4]&#10;Color: (220, 220, 220)" style="width: 40px; height: 40px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 5]&#10;Color: (220, 220, 220)" style="width: 40px; hei
# ...

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
#
# Modifier les valeurs de `ligne`, `colonne`, `R`, `G` et `B` avec des valeurs possibles.

# %%
grille[ligne, colonne] = (R, G, B)
grille  # pour voir

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exercice
# 1. Colorier le quadrillage représentant la grille qui s'affichera si on saisit le code donné ci-dessous.
# Vous pouvez écrire le nom exact de chaque couleur si vous ne possédez pas de crayon ayant la couleur précise.
#
# ```python
# grille = BlockGrid(8, 8, block_size=30, fill=(220, 220, 220))
#
# grille[2, 2] = (0, 0, 255)
# grille[5, 5] = (255, 0, 0)
# grille[0, 0] = (255, 255, 0)
# grille[7, 0] = ( 0, 255, 0)
# grille[0, 7] = (0, 255, 255)
# grille[7, 7] = (255, 0, 255)
#
# grille
# ```
#
# ![mat2.png](attachment:mat2.png)
#
#
# 2. Recopier le code dans une cellule et vérifier vos prédictions.

# %%
grille = BlockGrid(8, 8, block_size=30, fill=(220, 220, 220))

grille[2, 2] = (0, 0, 255)
grille[5, 5] = (255, 0, 0)
grille[0, 0] = (255, 255, 0)
grille[7, 0] = ( 0, 255, 0)
grille[0, 7] = (0, 255, 255)
grille[7, 7] = (255, 0, 255)

grille
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks93567f8c-5912-4c12-b71a-c0c5a8e3963a td {border: 1px solid white;}</style><table id="blocks93567f8c-5912-4c12-b71a-c0c5a8e3963a" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (255, 255, 0)" style="width: 30px; height: 30px;background-color: rgb(255, 255, 0);"></td><td title="Index: [0, 1]&#10;Color: (220, 220, 220)" style="width: 30px; height: 30px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 2]&#10;Color: (220, 220, 220)" style="width: 30px; height: 30px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 3]&#10;Color: (220, 220, 220)" style="width: 30px; height: 30px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 4]&#10;Color: (220, 220, 220)" style="width: 30px; height: 30px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 5]&#10;Color: (220, 220, 220)" style="width: 30px;
# ...

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Les images
# La grille contient 64 carrés : pour indiquer la couleur de chaque carré (ou pixel) il faut écrire 64 lignes de code !!!!
# Voyons sur l'exemple ci-dessous comment on peut procéder en considérant l'image comme un tableau de 8 lignes et 8 colonnes.
#
# Dans le code ci-dessous :
#
# * la variable `N` contient le triplet de valeurs de R, G, B pour avoir du noir
# * la variable `P` contient le triplet de valeur de R, G, B pour avoir du rose
# * la variable `matrice` contient une liste de listes contenant les triplets de couleurs de chaque carré de gauche à droite et de bas en haut. La disposition proposée, sous forme d'une matrice, n'est pas obligatoire mais utile pour visualiser ce que l'on fait.
#
#
#
# ```python
# N = (0, 0, 0)
# P = (255, 105, 180)
# matrice = [
#     [N, N, N, N, N, N, N, N],
#     [N, P, P, N, P, P, N, N],
#     [P, P, P, P, P, P, P, N],
#     [P, P, P, P, P, P, P, N],
#     [N, P, P, P, P, P, N, N],
#     [N, N, P, P, P, N, N, N],
#     [N, N, N, P, N, N, N, N],
#     [N, N, N, N, N, N, N, N]
#     ]
# ```

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exercice
# 1. Exécuter le code ci-dessous pour pouvoir utiliser le contenu de mat1.

# %%
N = (0, 0, 0)
P = (255, 105, 180)
matrice = [
    [N, N, N, N, N, N, N, N, N],
    [N, N, P, P, N, P, P, N, N],
    [N, P, P, P, P, P, P, P, N],
    [N, P, P, P, P, P, P, P, N],
    [N, N, P, P, P, P, P, N, N],
    [N, N, N, P, P, P, N, N, N],
    [N, N, N, N, P, N, N, N, N],
    [N, N, N, N, N, N, N, N, N]
    ]

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
#
# Pour pouvoir associer à chaque carré la couleur correspondante, on a écrit une fonction nommée `dessiner` et qu'il n'est pas nécessaire de comprendre pour l'utiliser.
# Exécuter la cellule pour pouvoir utiliser cette fonction.

# %%
def dessiner(mat):
    nb_lignes = len(mat)
    nb_colonnes = len(mat[0])
    grille = BlockGrid(nb_colonnes, nb_lignes, block_size=30)
    for ligne in range(nb_lignes):
        for colonne in range(nb_colonnes):
            grille[ligne, colonne] = mat[ligne][colonne]
    return grille

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Exécuter la cellule qui vous permettra de voir l'image construite à partir du contenu de la variable `matrice`.

# %%
dessiner(matrice)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocksec6a23d0-a1aa-4f39-a33f-e660c621ce81 td {border: 1px solid white;}</style><table id="blocksec6a23d0-a1aa-4f39-a33f-e660c621ce81" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 30px; height: 30px;background-color: rgb(0, 0, 0);"></td><td title=
# ...

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# Remplacer les `...` dans le code ci-dessous pour afficher la première lettre de votre prénom avec la couleur de votre choix et le fond de votre choix.
# **Faites d'abord un dessin sur un quadrillage de 8 sur 8.**
#
#
# Par exemple, pour la lettre Z on a :
# ![lettreZ.png](attachment:lettreZ.png)

# %%
# la variable F prend pour  valeur le triplet pour avoir la couleur du fond
F = (..., ..., ...) 
# la variable L prend pour valeur le triplet pour avoir la couleur de la lettre
L = (..., ..., ...)
matrice = [
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ...]
    ]

dessiner(matrice)

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Exercice
# Pour représenter une image donnée, on dessine une grille par dessus et on utilise le principe suivant : la couleur d'un carré doit correspondre à la couleur dominante du carré sur l'image initiale. On dit qu'on pixelise l'image. Cette règle peut être un peu adaptée pour obtenir un meilleur rendu.
#
# 1. Pixeliser l'image de Toad, en utilisant une grille de 12 sur 12.
#
# ![GrilleToad.png](attachment:GrilleToad.png)
#
# 2. Compléter le code ci-dessous qui va permettre d'afficher l'image de Toad pixellisé.

# %%
# pour le blanc
b = (..., ..., ...) # remplacer les ...
# pour le noir
n = (..., ..., ...)
# pour le vert
v = (..., ..., ...)
# pour le brun
br = (110, 44, 0)
# pour le chair
c = (250, 219, 216)

matrice = [
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],    
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...],
    [..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...]  
]


dessiner(matrice)

# %%
grille
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks735aed87-2ff9-4894-ae04-c823b1ab195b td {border: 1px solid white;}</style><table id="blocks735aed87-2ff9-4894-ae04-c823b1ab195b" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (220, 220, 220)" style="width: 60px; height: 60px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 1]&#10;Color: (220, 220, 220)" style="width: 60px; height: 60px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 2]&#10;Color: (220, 220, 220)" style="width: 60px; height: 60px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 3]&#10;Color: (220, 220, 220)" style="width: 60px; height: 60px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 4]&#10;Color: (220, 220, 220)" style="width: 60px; height: 60px;background-color: rgb(220, 220, 220);"></td><td title="Index: [0, 5]&#10;Color: (220, 220, 220)" style="width: 6
# ...

# %%
grille
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
# NameError: name 'grille' is not defined
# Error:
