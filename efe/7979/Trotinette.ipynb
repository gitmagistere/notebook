# %% [markdown]
# # <div class="alert alert-info" role="alert"> <center>Activité: Mouvement et vecteur vitesse d’un point

# %% [markdown]
# ![image 1 guidon.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Le programme ci-dessous permet de représenter la trajectoire d’un point du guidon de la trottinette. Mesurez les positions du point M avec une règle directement sur l'écran.
#
# Compléter les <b>lignes 4, 5 et 6 </b> puis exécuter le programme  <b>( sélectionner le cadre puis cliquer sur Shift et Entrée ).</b>
#
#
# &nbsp;
#
# <b>ATTENTION : </b> dans une liste, notée [ ] les différentes valeurs sont séparées par des virgules et pour les nombres décimaux, la virgule est le point du pavé numérique.
#
# <div class="alert alert-success" role="alert">
# <b>Remarques :</b>
# &nbsp;
#
# Pour faire fonctionner le programme , il faut exécuter toutes les cellules contenant du code dans l'ordre.

# %%
from matplotlib.pyplot import *
from numpy import *
#Pointage des positions d’un objet toutes les 0,40 s
dt = ........... # à compléter
x = [..............] # à compléter
y = [..............] # à compléter
#Affichage 
plot(x,y,'r-o')

ylim(0,6) # Donne les limites de l'axe des ordonnées
grid(True)

xlabel(" position x (m) ")
ylabel(" position y (m) ")
title(" Trajectoire d'un point du guidon d'une trottinette ")
show()

# %% [markdown]
# Dans cette partie nous créons une fonction qui permet de tracer chaque vecteur
# vitesse et de calculer leurs normes en chaque point.
#
# Exécuter le programme

# %%
 # Création de la fonction permettant de tracer un vecteur vitesse
def vecteur_vitesse(x, y, dt, i) :
    vx = (x[i+1] - x[i]) / dt 
    vy = (y[i+1] - y[i]) / dt   

    quiver(x[i], y[i], vx, vy, scale_units='xy',angles='xy',color='blue',width=0.010,scale=4)    
    vitesse = sqrt(((x[i+1]-x[i])/(dt))**2 +((y[i+1]-y[i])/(dt))**2) # Calcul de la vitesse au point i
    print("A la position M",i, " la vitesse est de",round(vitesse,1), "m/s")
    text(x[i]+0.20,y[i]+0.50,r"$\vec{v}$"+str(i),color="blue") #permet d'afficher le nom à côté du vecteur
    
#Affichage 
plot(x, y, 'r--o')
vecteur_vitesse(x, y, dt, 0) #tracé du vecteur vitesse au point M0
vecteur_vitesse(x, y, dt, 1) #tracé du vecteur vitesse au point M1
vecteur_vitesse(x, y, dt, 2) #tracé du vecteur vitesse au point M2
vecteur_vitesse(x, y, dt, 3) #tracé du vecteur vitesse au point M3
vecteur_vitesse(x, y, dt, 4) #tracé du vecteur vitesse au point M4

ylim(0,6)
grid(True)
xlabel(" Position x (m) ")
ylabel(" Position y (m) ")
title(" modélisation de la vitesse ")
show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   import sys
# A la position M 0  la vitesse est de 3.0 m/s
# A la position M 1  la vitesse est de 4.1 m/s
# A la position M 2  la vitesse est de 4.9 m/s
# A la position M 3  la vitesse est de 5.3 m/s
# A la position M 4  la vitesse est de 6.2 m/s

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Voici une nouvelle trajectoire du même point M du guidon de la trottinette dans le référentiel lié à la route lors d’un parcours plus vallonné.
#
#
#
# &nbsp;
#
# Vous pouvez vous entrainer avec les 2 programmes précédents pour les calculs et les tracés de vecteurs.

# %% [markdown]
# ![image 2 guidon.JPG](data:image/jpeg;base64,...)
