# %% [markdown]
# <h1><center><span style="border-style:solid;border-width:1px;border-radius:5px;
#     padding:5px;background-color:lightpink;box-shadow: 6px 6px 6px black;">Boucles bornées</span></center></h1>

# %% [markdown]
#
# Dans la suite, vous devez exécutez les cellules de code <strong>Entrée[ ]</strong> en cliquant sur  Exécuter ou en appuyant sur [Maj]+[Entrée].
#
# N'oubliez pas d'enregister régulièrement votre travail.
# </p>

# %% [markdown]
# # 1- Définition de la boucle bornée "for"

# %% [markdown]
# Une **boucle** permet de répéter des instructions. Lorsqu'on connaît à l'avance le nombre de répétitions, on parle de **boucle bornée**. L'instruction <code>for</code> (pour) permet  de créer une boucle bornée.

# %% [markdown]
# En langage Python, la syntaxe d'une boucle for est la suivante :

# %%
for i in range(...):
    instruction(s)

# %% [markdown]
# **Remarques**
#
# * La fonction <code>range()</code> permet d'énumérer le nombre de passages dans la boucle bornée. Elle peut être appelée de différentes façons :
#
# 1) <code>range(n)</code>, où <code>n</code> est un entier, fait prendre à la variable <code>i</code> les valeurs entières de 0 à n-1, donc n valeurs ;
#
# 2) <code>range(n,m)</code>, où <code>n</code> et <code>m</code> sont des entiers, fait prendre à la variable <code>i</code> les valeurs entières de n à m-1 ;
#
# 3) <code>range(n,m,k)</code>, où <code>n</code>, <code>m</code> et <code>k</code> sont des entiers, fait prendre à la variable <code>i</code> les valeurs entières de n à m-1 avec un pas de k.
#
# * La variable <code>i</code> n'est pas forcément utilisée dans les instructions à répéter, on l'appelle **compteur**.
#
# * Les instructions à répéter sont indentées : il n'y a pas d'instructions pour signaler la fin de la boucle, c'est l'indentation qui indique les instructions faisant partie de la boucle.

# %% [markdown]
# # 2- Exercices

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 1 : </strong>Exécuter les instructions ci-dessous.
#
# </div>

# %%
for i in range(4):
    print(2*i)
# Out:
# 0
# 2
# 4
# 6

# %%
for i in range(1,5):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16

# %%
a=1
for i in range(3):
    a=a*2
    print(a)
# Out:
# 2
# 4
# 8

# %% [markdown]
# <div class="alert alert-info">Compléter les instructions ci-dessous qui permettent d'afficher les cubes de tous les entiers de 0 à 9.
#
# </div>

# %%
for i in range(10):
    print(i**3)
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 2 :  </strong> Que vaut la variable <code>s</code> après l'exécution des instructions ci-dessous ?
#
# </div>

# %%
s=0
for i in range(6):
    s=s+i

# %% [markdown]
# **Réponse** : 15

# %% [markdown]
# <div class="alert alert-info">Vérifier votre réponse en exécutant l'instruction ci-dessous.
#
# </div>

# %%
s
# Out:
# 15

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 3 : </strong>  Un bijou précieux estimé à une valeur de 2 000 € voit sa valeur  augmenter de 4 % chaque année.
#     On rappelle qu'augmenter une quantité de 4 % revient à multiplier cette quantité par $1+\dfrac{4}{100}$ soit $1,04$.
#     Compléter le script de la fonction <code>prix</code> d'argument <code>n</code> afin qu'elle renvoie la valeur du bijou au bout de n années.
#
# </div>

# %%
def prix(n):
    P=2000
    for i in range(n):
        P=P*1.04
    return P

# %% [markdown]
# <div class="alert alert-info">
#     Tester votre fonction et vérifier qu'au bout de 10 ans la valeur du bijou est d'environ 2 960 €.
# </div>

# %%
prix(10)
# Out:
# 2960.488569836689

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 4 : </strong> On considère la fonction ci-dessous dont l'argument <code>a</code> est un nombre entier naturel non nul :
# </div>

# %%
def nbdiv(a):
    n=0
    for i in range(1,a+1):
        if a%i==0:
            n=n+1
    return n

# %% [markdown]
# <div class="alert alert-info" >
#     Répondre aux questions suivantes :
# </div>

# %% [markdown]
# 1) Que teste l'instruction <code>a%i==0</code> ? <b> La divisibilité de a par i </b>
#
# 2) Que renvoie <code>nbdiv(6)</code> ? <b> Le nombre de diviseurs de 6 à savoir 4 </b>
#
# 3) Que renvoie cette fonction pour un entier naturel a non nul ? <b>Le nombre de diviseurs de a</b>

# %% [markdown]
# <div class="alert alert-info" >
#     Exécuter les instructions ci-dessous afin de vérifier vos réponses.
# </div>

# %%
nbdiv(6)
# Out:
# 4

# %%
nbdiv(13)
# Out:
# 2

# %%
nbdiv(16)
# Out:
# 5

# %%
nbdiv(31)
# Out:
# 2

# %% [markdown]
# <div class="alert alert-info" >
#     Que renvoie <code>nbdiv(a)</code> lorsque le nombre a est un nombre premier ?
# </div>

# %% [markdown]
# **Réponse** :<b> 2 car un nombre premier par défintion admet exactement deux diviseurs !</b>

# %% [markdown]
# <div class="alert alert-info">Compléter le script de la fonction <code>nbpremier</code> d'argument  <code>a</code> un entier naturel non nul qui permet de déterminer si cet entier a est premier et qui utilise la fonction <code>nbdiv</code>.
# </div>

# %%
def nbpremier(a):
    if nbdiv(a) == 2 :
        return "le nombre",a,"est premier" 
    else:
        return "le nombre",a,"n'est pas premier"

# %% [markdown]
# <div class="alert alert-info">Tester votre fonction.
# </div>

# %%
nbpremier(2)
# Out:
# ('le nombre', 2, 'est premier')

# %%
nbpremier(10)
# Out:
# ('le nombre', 10, "n'est pas premier")

# %%
nbpremier(31)
# Out:
# ('le nombre', 31, 'est premier')
