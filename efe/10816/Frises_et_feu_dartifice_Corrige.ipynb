# %% [markdown]
# <div style="display:flex; align-items:center; border: 2px dashed #ffa90b; border-left:15px solid #ffa90b; padding:15px;">
#     <div style="padding-top:7px;"><img src ="https://upload.wikimedia.org/wikipedia/commons/thumb/f/f8/Python_logo_and_wordmark.svg/197px-Python_logo_and_wordmark.svg.png" alt="Logo de Python" /></div>
#     <span style="font-size:270%; padding-top:18px; color:#7b7b7b;">& tortue : frises, feu d’artifice</span>
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#     <b>Objectif.</b> Utiliser la tortue du <i>langage Python</i> pour tracer des figures complexes.
# </div>

# %% [markdown]
# À la fin de cette activité, on pourra dessiner des figures comme celle-ci : 😎
#
# ![feu.png](attachment:feu.png)

# %% [markdown]
# <div class="alert alert-success" style="border-left: 15px solid #3c763d;">
#     Pensez à bien <b>exécuter</b> à chaque fois les instructions en Python avec [Maj]+[Entrée].<br />
# </div>

# %% [markdown]
# # 1. Un peu d’aléatoire <a name="alea"></a>

# %% [markdown]
# <div class="alert alert-success" style="border-left: 15px solid #3c763d;">
#     <b>Exécutez</b> les instructions ci-dessous, <i>plusieurs fois</i>. Remarquez que le tracé change à chaque fois.
# </div>

# %%
from turtle import *
from random import *
def triangle(taille):
    for cote in range(3):
        forward(taille)
        right(120)
speed(7)

for motif in range(10):
    triangle(randint(10, 250))

done()

# %% [markdown]
# <div class="alert alert-danger" style="border-left: 15px solid #a94442;">
#     <b>Explication.</b> Dans le module <span style="font-family:courier new;font-size:115%">random</span> chargé au début, la fonction <span style="font-family:courier new;font-size:115%">randint(a, b)</span> donne un nombre entier au hasard entre <i>a</i> et <i>b</i>.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-left: 15px solid #3c763d;">
#     <b>Exécutez</b> plusieurs fois cet autre exemple, ci-dessous, pour mieux comprendre le fonctionnement de <span style="font-family:courier new;font-size:115%">randint(a, b)</span>.
# </div>

# %%
from random import *

def polygone(n):
    for cote in range(n):
        forward(70)
        right(360 / n)

speed(7)
penup()
goto(0, 150)
pendown()

# İNTÉRESSEZ-VOUS SURTOUT AUX LİGNES ÉCRİTES Cİ-DESSOUS :

for motif in range(4):
    polygone(randint(3, 15))

done()

# %% [markdown]
# <div class="alert alert-warning" style="border-left:15px solid #8a6d3b;">
#     <b>Explication.</b> On répète 4 fois le tracé d’un polygone, dont le nombre de côtés est choisi au hasard entre 3 côtés et 15 côtés.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#     <b>À vous de jouer&nbsp;!</b> On veut obtenir une figure similaire à celle ci-dessous. Compléter les instructions et exécuter :
# </div>

# %% [markdown]
# ![frise.png](attachment:frise.png)

# %%
from random import *

speed(10)  # À NOUVEAU, LA VİTESSE EST MİSE À 1 POUR VOUS AİDER À COMPRENDRE, VOUS LA METTREZ À 10 À LA FIN.
penup()
goto(-310, -20)
pendown()

def triangle(taille):
    for cote in range(3):
        forward(taille)
        right(120)
        
        

for motif in range(12):
    L = randint(10, 100)  # ON CHOİSİT UN ENTİER AU HASARD ENTRE 10 ET 100, ET ON APPELLE CETTE LONGUEUR « L ».
    left(60)
    triangle(L)
    right(60)
    forward(L)
done()

# %% [markdown]
# # 2. Le feu d’artifice ! <a name="feu"></a>

# %% [markdown]
# ### Première étape
# İl faut dessiner _un_ feu d’artifice !
# ![un-feu.png](attachment:un-feu.png)

# %% [markdown]
# <div class="alert alert-success" style="border-left: 15px solid #3c763d;">
#     <b>Exécutez</b> les instructions définies ci-dessus puis jouez plus bas avec les paramètres L (longueur des « traits ») et n (nombre de traits) pour obtenir un « feu d’artifice » comme ci-dessus.
# </div>

# %%
def feu(L, n):
    speed(10)
    for trait in range(n):
        forward(L)
        backward(L)
        right(360 / n)

# %%
feu(100,30)
done()

# %% [markdown]
# ### Deuxième étape
#
# On en trace quelques-uns de tailles différentes, à des endroits aléatoires :
#
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#     <b>Compléter</b> et exécutez pour obtenir quelque chose de similaire à cette figure :
# </div>
#
# ![feu-noir.png](attachment:feu-noir.png)

# %%
for combien in range(...): # COMBİEN VEUT-ON DE FEUX D’ARTİFİCE ?
    penup()
    goto(randint(-300,300), randint(-160,160)) # EXPLICATİON : LA TORTUE VA À UN ENDROİT (x;y) AU HASARD
    pendown()
    L = randint(..., ...) # LONGUEURS MİNİMALE ET MAXİMALE DES « TRAİTS »
    n = randint(..., ...) # COMBİEN DE « TRAİTS » POUR CHAQUE FEU ?
    feu(L, n)
done()

# %% [markdown]
# ### Dernière étape
#
# On ajoute la couleur ! 😎
#
# <div class="alert alert-info" style="border-left:15px solid #31708f;">
#     <b>Complétez</b> les passages nécessaires, et profitez du spectacle !
# </div>

# %%
from turtle import *
from random import *

couleurs = ("darkred", "red", "tomato", "orange",
            "green", "teal", "darkgreen", 
            "blue", "steelblue", "dodgerblue",
            "darkviolet", "mediumblue")

speed(10)
for combien in range(10): # COMBİEN DE FEUX D’ARTİFİCE ?
    penup()
    goto(randint(-300,300), randint(-160,160))
    pendown()
    color(couleurs[randint(0,11)])
    L = randint(10, 20) # LONGUEURS MİNİMALE ET MAXİMALE DES « TRAİTS »
    n = randint(3, 20) # COMBİEN DE « TRAİTS » POUR CHAQUE FEU ?
    feu(L, n)
done()

# %% [markdown]
# <div class="alert alert-warning" style="border-left:15px solid #8a6d3b;">
#     <b>Résumé des instructions utiles.</b> Au cours de cette activité, on a découvert :<br/><ul>
#     <li><span style="font-family:courier new;font-size:115%">from random import *</span> &nbsp; &nbsp; pour pouvoir utiliser des nombres aléatoires</li>
#     <li><span style="font-family:courier new;font-size:115%">randint(a, b)</span> &nbsp; &nbsp; pour avoir un entier choisi au hasard entre a et b</li>
#     <li><span style="font-family:courier new;font-size:115%">speed(x)</span> &nbsp; &nbsp; pour faire avancer la tortue plus ou moins vite (de 1 à 10)</li>
#     <li><span style="font-family:courier new;font-size:115%">penup()</span> &nbsp; &nbsp; pour lever le crayon (ne pas dessiner quand la tortue se déplace)</li>
#     <li><span style="font-family:courier new;font-size:115%">pendown()</span> &nbsp; &nbsp; pour basser le crayon (dessiner quand la tortue se déplace)</li>
#     <li><span style="font-family:courier new;font-size:115%">goto(x, y)</span> &nbsp; &nbsp; pour placer la tortue au point de coordonnées (x;y).
#     </ul>
# </div>
