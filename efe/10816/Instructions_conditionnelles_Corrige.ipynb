# %% [markdown]
# <h1><center><span style="border-style:solid;border-width:1px;border-radius:5px;
#     padding:5px;background-color:lightpink;box-shadow: 6px 6px 6px black;">Instruction conditionnelle</span></center></h1>

# %% [markdown]
#
# Dans la suite, vous devez exécutez les cellules de code <strong>Entrée[ ]</strong> en cliquant sur  Exécuter ou en appuyant sur [Maj]+[Entrée].
#
# N'oubliez pas d'enregister régulièrement votre travail.
# </p>

# %% [markdown]
# # 1- Définir l'Instruction conditionnelle

# %% [markdown]
# Une instruction conditionnelle permet d'effectuer des choix dans un programme en fonction de la valeur vraie ou fausse d'une condition :
#
# * si la condition est vraie, on effectue des instructions ;
#
# * si la condition est fausse, on effectue d'autres instructions.

# %% [markdown]
# **Exemple 1**
#
# On suppose qu'un magasin de reprographie applique les tarifs suivants :
#
# * 0,15 € l'unité jusqu'à 50 photocopies ;
#
# * 0,10 € au-delà.
#
# Voici le script d'une fonction <code>prix_photocopies</code> qui prend comme argument le nombre <code>n</code> de photocopies et qui renvoie le prix à payer :

# %%
def prix_photocopies(n):
    if n<=50:
       prix=0.15*n
    else:
       prix=0.10*n
    return(prix)

# %% [markdown]
# **Remarques**
#
# * La condition <code>n<=50</code> correspond à "n inférieur ou égal à 50".
#
# * Au niveau des lignes 3 et 5 il y a une indentation car les lignes précédentes se terminent par <code>:</code>. Le retour à l'indentation précédente aux lignes 4 et 6, qui ne se fait pas automatiquement, signale la fin du bloc d'instructions.

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 1 : </strong> Utiliser la fonction précédente pour calculer le prix à payer pour 25 photocopies, puis le prix à payer pour 75 photocopies.
# </div>

# %%
prix_photocopies(25)
# Out:
# 3.75

# %%
prix_photocopies(75)
# Out:
# 7.5

# %% [markdown]
# **Exemple 2**
#
# Dans un parc d’attractions qui possède des manèges un peu « sportifs », le prix de l’entrée dépend de la taille et de l’âge de la personne.
#
# La fonction ci-dessous permet de déterminer le prix à payer par une personne selon sa taille en cm et son âge en années :

# %%
def prix(taille,age):
    if taille<90:
        entree=0
    elif 90<=taille<130:
        entree=age*0.5
    else:
        entree=age*1.1
    return entree

# %% [markdown]
# **Remarque**
#
# L'instruction <code>elif</code> est la contraction de <code>else if</code>. Son utilisation permet de tester deux conditions ou plus et évite de devoir imbriquer des instructions conditionnelles les unes dans les autres.

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 1 : </strong> Utiliser cette fonction pour déterminer le prix à payer pour une personne de 18 ans mesurant 1,82 m, puis le prix à payer pour un enfant de 8 ans qui mesure 1,20 m.
# </div>

# %%
prix(182,18)
# Out:
# 19.8

# %%
prix(120,8)
# Out:
# 4.0

# %% [markdown]
# # 2- Exercices

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 2 : </strong> Compléter le script de la fonction <code>mini</code> qui prend comme argument deux nombres distincts <code>a</code> et <code>b</code> et qui renvoie le plus petit de ces deux nombres.
# </div>

# %%
def mini(a,b):
    if a<b:
        return a
    else:
        return b

# %% [markdown]
# <div class="alert alert-info">Tester votre fonction.
# </div>

# %%
mini(-120,-12)
# Out:
# -120

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 3 : </strong> Ecrire le script de la fonction <code>parité_2</code> qui prend comme argument un nombre entier <code>n</code> et qui renvoie le message "ce nombre est pair" si <code>n</code> est pair et le message "ce nombre est impair" sinon.
# </div>

# %%
def parité_2(n):
    if n%2 == 0:
        print("ce nombre est pair")
    else:
        print("ce nombre est impair")

# %% [markdown]
# <div class="alert alert-info">Tester votre fonction.
# </div>

# %%
parité_2(10021458721231397)
# Out:
# ce nombre est impair

# %% [markdown]
# <div class="alert alert-info"><strong>Exercice 4 : </strong> Jérémy a écrit le script de la fonction <code>ma_fonction</code>.
# Ce script contient deux erreurs. Expliquer lesquelles.

# %%
def ma_fonction(x):
    if x<2:
        y=x+1
    elif x=2:
        y=3*x
    else:
        y=4-x
return y
# Out:
#   File "<input>", line 4
#     elif x=2:
#          ^^^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
# Error:

# %% [markdown]
# **Réponse :** 1) elif x==2 au lieu de x=2 2) indentation avant return y

# %%
ma_fonction(12)
# Out:
# Traceback (most recent call last):
#   File "<input>", line 1, in <module>
# NameError: name 'ma_fonction' is not defined
# Error:

# %%
def ma_fonction(x):
    if x<2:
        y=x+1
    elif x==2:
        y=3*x
    else:
        y=4-x
    return y

# %%
ma_fonction(12)
# Out:
# -8
