# %% [markdown]
#  # <span style="color:#8E44AD" id="3"><center> Tri fusion </center></span>

# %% [markdown]
# ## Diviser pour régner
# <br>
# <br>
# Le diviser pour régner est une méthode algorithmique basée sur le principe suivant <br>
# On prend un problème (généralement complexe à résoudre), on divise ce problème en une multitude de petits problèmes, l'idée étant que les petits problèmes sont plus simples à résoudre que le problème d'origine. Une
# fois les petits problèmes résolus, on les recombine afin d'obtenir la solution du problème de départ.<br>
# <br>
# Le paradigme diviser pour régner repose sur trois étapes : <br>
# – <b>DIVISER </b> : le problème d'origine est divisé en sous-problèmes <br>
# – <b>RÉGNER</b> : on résout les sous-problèmes<br>
# – <b>COMBINER</b> : Les solutions des sous-problèmes sont combinées afin d'obtenir la solution du problème d'origine.<br>
# <br>
# Les algorithmes basés sur le paradigme « diviser pour régner » sont très souvent des algorithmes récursifs.<br>
# <br>
# Nous avons déjà étudié les algorithmes de tri : le tri par insertion et le tri par sélection. Nous allons maintenant étudier une nouvelle méthode de tri, le tri fusion.<br>
# Comme pour les autres algorithmes, cet algorithme de tri fusion prend en entrée une liste non triée et donne
# en sortie la « même » liste triée. <br>

# %% [markdown]
# <br>
#
# <div style="
#   border: 2px solid black;
#   background-color: #fff;
#   padding: 20px;
#   margin: 20px 0;
#   color: #000;
#   font-family: Arial, sans-serif;
#   box-shadow: 4px 4px 12px rgba(0, 0, 0, 0.2);
# ">
#   <h3 style="margin-top: 0;">I- Tri fusion à la main</h3>
#   <p>
#       <br>
#     <b>Principe</b> <br>
#       <br>
#     L'algorithme de tri fusion inventé en 1945 par John Von Neumann se décrit simplement de manière
#     récursive :<br>
#     - Si la liste a 0 ou 1 élément, elle est déjà triée <br>
#     - Si la liste a plus d'un élément, on la partage en deux listes et on applique le tri fusion sur chacune des deux listes <br>
#     - On fusionne les résultats.<br>
#     Pour fusionner deux listes triées, on compare les éléments de chacune des deux listes et on déplace le plus petit dans une nouvelle liste.<br>
#       Lorsque l'une des deux listes est vide, on déplace les éléments restants de la seconde.
#   </p>
#   <p>
#   </p>
# </div>

# %% [markdown]
# ![image_bc97d954](attachment:image_bc97d954)
#
# <p>
#   <br>
#   <br>
#
# 1) Appliquer l'algorithme de tri fusion à la liste <b>L =[100, 25, 13 ,90, 3, 67, 5, 9 ]</b>.<br>
#
#     <br>
#
# 2) De nouveau appliquer l'algorithme de tri fusion à la liste <b> L=[ 21, 8, 7, 2, 5, 1 ] </b> . <br>
# Expliquer les écueils rencontrés et vos initiatives afin de les contourner sur une liste de longueur n un entier naturel.
#     <br>
#     </p>

# %% [markdown]
# <br>
# <br>
# <h3 style="margin-top: 0;">II- Implémentation du tri fusion</h3>
# <br>
# <br>
# <p>
#     <ol>
#         <li>Ecrire une fonction <b> <i>fusion</i> </b> qui prend en entrée deux listes triées (liste1, liste2) et retourne en sortie une
# liste triée.</li><br>
#         <li>Ecrire une fonction récursive <b> <i>tri_fusion </i> </b>qui prend en entrée une liste non triée et retourne en sortie la liste triée.</li>
#
# </ol>
#     <br>
#     <br>
#
# <p/>
#
# ![image_6f3b9bb8](attachment:image_6f3b9bb8)

# %% [markdown]
# <br>
# <br>
# <h3 style="margin-top: 0;">III- Efficacité du tri fusion</h3>
# <br>
# <br>
#  <p>
#         Dans cette partie, nous « jugerons » l'efficacité du tri fusion en comparant avec les algorithmes de tri vus en première, le tri par insertion et le tri par sélection. Lequel de ces tris est le plus performant ?
#
# 1. Expliquer le rôle de la fonction <b> <i>genere_l</i> </b>.
#
#     <br>
#     <br>
#
#     <p/>
#
# ![image_0fe3cd7b](attachment:image_0fe3cd7b)

# %% [markdown]
# <br>
# <br>
#  <p>
#
# 2. Après avoir importer la bibliothèque <b> <i>time</i> </b>, vous écrirez une fonction temps_fusion, qui prendra en entrée une liste et retournera en sortie, le temps nécessaire pour trier cette liste avec le tri fusion.<br>
#
#     <br>
#
# 3. Voici les codes en langage Python des tri par sélection et par insertion.<br>
#     Comme à la question précédente, écrire deux nouvelles fonctions <b> <i>temps_selection</i> </b> et <b> <i>temps_insertion</i> </b> qui
# calculeront les temps nécessaires pour trier une liste avec les tris par sélection et insertion.
#
#     <br>
#     <br>
#
#     <p/>
#
# ![image_8d317c3f](attachment:image_8d317c3f)

# %% [markdown]
# <br>
# <br>
#  <p>
#
# 4. Comparer les temps d'exécution sur des listes aléatoires de taille n=100 , n=1000 n=10000 et
# n=40000. <br>
#
#
#     <br>
#
# 5.  La fonction ci-contre affiche sur un même graphique les temps d'éxecution des trois tris, fusion, sélection et insertion en fonction de la taille n de listes générées aléatoirement.<br>
#     Lequel de ces tris semble le plus performant ?
#
#
#     <br>
#     <br>
#
#     <p/>
#
# ![image_1e28162b](attachment:image_1e28162b)

# %% [markdown]
# <br>
# <br>
#  <p>
#
# 6. Rappeler les complexités des tris par sélection et par insertion puis effectuer une petite recherche afin de déterminer la compléxité du tri fusion. <br>
#
#
#     <br>
#
#
#
#
#     <br>
#     <br>
#
#     <p/>
