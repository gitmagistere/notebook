# %% [markdown]
# # 1. Simulation d'un échantillon et loi des grands nombres

# %% [raw]
# Pour cette simulation, on va utiliser le module random et la fonction randint du module random, randint(1,6) qui renvoie un entier pseudo-aléatoire entre 1 et 6.
#
# On veut programmer une fonction echantillon qui permet de renvoyer la fréquence d'apparition de la somme 7 pour un échantillon de taille n.

# %% [raw]
# 1. Compléter le programme ci-dessous.

# %%
from random import*

def echantillon(n):
    compteur=0
#la variable compteur compte le nombre de fois que la somme des faces vaut 7
    for i in range(n):
        de1=...
        de2=...
        somme=
        if somme==7:
            compteur=...
    frequence=...
    return(frequence)

# %% [raw]
# 2. Tester dans la cellule ci-dessous le programme avec différentes valeurs de n.

# %% [markdown]
# ## Représentation graphique de la stabilisation des fréquences autour de la probabilité théorique

# %% [markdown]
# On veut représenter graphiquement la fluctuation des fréquences autour de la probabilité théorique $p=\frac{1}{6}$
#
# On va pour cela créer une fonction graphique qui créera dans un premier temps une liste "frequences" stockant au fur et à mesure les différentes fréquences.

# %%
import matplotlib.pyplot as plt

def graphique (n):
    frequences=[]
    '''la boucle for ci-dessous permettra de créer par ajouts successifs une liste frequences 
    qui vaudra [echantillon(1),echantillon(2),...,echantillon(n)]'''
    for i in range(1,n+1):
        frequences.append(...)
    NombreLancers=[i for i in range(1,n+1)]
    p=[1/6 for i in range(1,n+1)]
    plt.clf()
    # l'instruction plt.clf() permet d'effacer les tracés précédents
    plt.scatter(NombreLancers,frequences,marker='+')
    plt.plot(NombreLancers,p,'k')
    plt.show()

# %% [raw]
# 3. Tester dans la cellule ci-dessous le programme avec différentes valeurs de n

# %% [markdown]
# # 2. Fluctuation d'échantillonnage

# %% [markdown]
# Le programme de mathématiques invite à observer avec quelle probabilité la fréquence 𝑓 se retrouve dans l’intervalle de fluctuation $[𝑝 − \frac{1}{\sqrt{n}}, 𝑝 + \frac{1}{\sqrt{n}} ]$.
#
# La fonction fluctuation ci-dessous permet d'en avoir un aperçu graphique en simulant un certain nombre d'échantillons de taille n .

# %% [raw]
# Compléter le programme ci-dessous puis tester le avec différentes valeurs de n et NbEchantillons

# %%
from math import*

def fluctuation(n,NbEchantillons):
    '''n est la taille de chaque échantillon et 
    NbEchantillons le nombre d’échantillons sur lesquels on mène l’observation'''
    '''a (resp.b) désigne la borne inférieure(resp.supérieure) de l'intervalle de fluctuation'''
    a=...
    b=....
    frequences=[]
    '''la liste frequences contiendrales fréquences des NbEchantillons échantillons de taille n'''
    for i in range(NbEchantillons):
        frequences.append(...)
    N=[i for i in range(1,NbEchantillons+1)]
    '''la liste p est constituée de valeurs toutes égales à la probabilité théorique, 1/6
    la liste borne1 est constituée de valeurs toutes égales à la borne inférieure
    la liste borne2 est constituée de valeurs toutes égales à la borne supérieure
    '''
    p=[.... for i in range(1,...)]
    borne1=[... for i in range(1,...)]
    borne2=[... for i in range(1,...)]
    plt.clf()
    plt.scatter(N,frequences,marker='+')
    plt.plot(N,p,'k')
    plt.plot(N,borne1,'r')
    plt.plot(N,borne2,'r')
    plt.show()
