# %% [markdown]
# # A l'aide d'un logiciel de pointage vidéo, on repère les positions successives d'un système {ballon de basket} au cours de son mouvement, lors d'un lancer.

# %% [markdown]
# ![Capture d’écran 2022-02-05 à 17.35.46.png](data:image/png;base64,...)

# %% [markdown]
# Le programme ci-dessous permet de représenter, pour chaque position, les vecteurs variation de vitesse et de calculer le produit ![Capture d’écran 2022-02-05 à 17.36.04.png](data:image/png;base64,...)

# %% [markdown]
# ⏩**Exécuter le programme en appuyant successivement sur chacune des flèches des cellules de codes, puis répondre aux questions.**

# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import pandas as pd

# Mesures issues du pointage vidéo
#x = [0,0.533,1.067,1.600,2.133,2.667,3.2,3.733,4.267]
#y = [2.2,2.638,2.902,2.992,2.908,2.649,2.216,1.609,0.828]
#t = [0,0.133333333,0.266666667,0.4,0.533333333,0.66666667,0.8,0.933333333,1.066666667]

# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_excel("/content/drive/MyDrive/Data/pointage.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c1b90d7c670b> in <cell line: 1>()
# ----> 1 df=pd.read_excel("/content/drive/MyDrive/Data/pointage.xlsx")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# **Question 1** : A quoi servent les lignes suivantes ? Justifier la réponse.

# %%
Vx=[]
for i in range(len(x)-1) :
    Vx=Vx+[(x[i+1]-x[i])/(t[i+1]-t[i])]

Vy=[]
for i in range(len(y)-1) :
    Vy=Vy+[(y[i+1]-y[i])/(t[i+1]-t[i])]

# %% [markdown]
# **Question 2** : Dans le programme, repérer et justifier l'écriture des lignes permettant le calcul du produit
#  ![Capture d’écran 2022-02-05 à 17.36.04.png](data:image/png;base64,...)

# %% [markdown]
# **Question 3** : Trouver alors la masse du ballon.

# %%
#Calcul des coordonnées des vecteurs variation de vitesse et du produit m*Delta v/Delta t
DVx=[]
for i in range(len(Vx)-1) :
    DVx=DVx+[(Vx[i+1]-Vx[i])]

DVy=[]
for i in range(len(Vy)-1) :
    DVy=DVy+[(Vy[i+1]-Vy[i])]

DV=[]
for i in range(len(DVy)) :
    DV=DV+[0.600*(DVx[i]**2+DVy[i]**2)**0.5/(t[i+1]-t[i])]

#tracé des positions et des vecteurs variation vitesse
for i in range(len(t)-2):
    plt.plot(0,0,x[i],y[i],'ro')
    plt.arrow(x[i],y[i],DVx[i],DVy[i], color='b',head_width=0.1, head_length=0.10, length_includes_head=True)
    plt.text(x[i]+0.05,y[i]-0.15,"$\overrightarrow{\Delta v}$"+str(i+1),color="blue")
    print('Au point',i+1, 'le produit m*Delta v/Delta t, vaut',round(DV[i],2),' kg. m/s²')
#Légende
plt.text(1.6,0.5,"Échelle :    1 m/s",  color="blue")
plt.plot([2,2],[0,1],'_-',color='blue')
plt.grid()
plt.title("Tracé des vecteurs variation de vitesse")
plt.xlabel('x (m)')
plt.ylabel('y (m)')
#tracé des points de la courbe
plt.savefig("Courbe-deltaV.png")
plt.show()

# %% [markdown]
# **Question 4** : Faire le bilan des forces s'appliquant au système. On négligera l'action des frottements de l'air.
#
# **Question 5** : Rappeler la relation liant de façon approchée la variation du vecteur vitesse et la somme des forces extérieures. Utiliser le programme pour vérifier la relation dans cet exemple de mouvement.

# %% [markdown]
# **Question 6 (Pour les plus rapides)** : Vérifier que la relation est vérifiée dans le cas d'un autre pointage vidéo. Utiliser le document pointage2 pour modifier le programme et rédiger une réponse argumentée.
