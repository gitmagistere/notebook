# %% [markdown]
# # **Entraînement en Python**
#
# Dans cet entrainement, l'objectif est de vous former à la programmation en langage Python pour comprendre que toutes les traitements possible d'images numériques (luminosité, colorimétrie, netteté, ...) sont réalisés grâce aux algorithmes !!!
#
# Vous allez donc effectuer du traitement d'image par programmation en langage Python. L'image utilisée dans cet entraînement est l'appareil photo ci-dessous. Vous devez l'importer dans le dossier du volet de gauche. Ses dimensions sont : 200 x 200 pixels.
#
# ![APhoto.jpg](attachment:APhoto.jpg)

# %% [markdown]
# ## **Exercice 1 : Afficher la valeur de tous les pixels d’une image.**

# %% [markdown]
# Ce programme affiche les 3 composantes r,v et b de chaque pixel des coordonnées (1, 1) aux coordonnées (200, 200) sur l'image APhoto.jpg
#
# r, v et b sont 3 variables.
#
# 1. Cependant des erreurs de programmation se sont glissées dans le programme ci-dessous. En exécutant le code vous verrez apparaitre des messages d'erreurs qui vous permettront d'identifier où elles se trouvent et de les corriger. Vous parviendrez à faire fonctionner ce code par une suite d'essais/erreurs/corrections. A vous de jouer !

# %% [markdown]
# 1- Exécuter le programme ci-dessous en cliquant sur le petit triangle "Play" :

# %%
from PIL import image
img = Image.open("AFoto.jpg")
largeur_image=200
hauteur_image=200
for y in range(hauteur_image)
    for x in range(largeur_image)
        R,V,B=img.getpixel((x,y))
        PRINT("pixel(",x,",",y,") --> rouge : ",r,", vert : ",v,", bleu : ",b)
PRINT("fin")

# %% [markdown]
# Remarque : On voit que ce programme affiche successivement les valeurs R,V et B de chaque pixel de l'image **ligne par ligne**.
#
# 2. Copiez/coller le programme ci-dessus dans la cellule de code ci-dessous puis modifiez-le pour qu'il affiche les valeurs R,V et B de chaque pixel **colonne par colonne**.

# %%
"""
Vous pouvez tester votre programme de la question 2 dans cette cellule (après les 3 guillemets)...
"""

# %% [markdown]
# 3. Réécrivez le programme dans la cellule ci-dessous en utilisant la boucle **while**.

# %%
"""
Vous pouvez tester votre programme de la question 3 dans cette cellule (après les 3 guillemets)...
"""

# %% [markdown]
# ## **Exercice 2 : Modifier la valeur de tous les pixels d'une image dans une dominante de couleur !**

# %% [markdown]
# Ce programme permet de simuler un algorithme de traitement d'image simple. Il doit modifier la valeur de tous les pixels d'une image dans une dominante de couleur bleue. Cependant quelques erreurs se sont glissées dans le code, à vous de les retrouver !!!
#
# 1. Exécuter le programme ci-dessous en cliquant sur le petit triangle "Play" :

# %%
from PIL import Image
img = image.open("APhoto.jpg")
largeur_image=100
hauteur_image=100
y=0
While (y<hauteur_image)
    y+=1
    x=0
    While x<(largeur_image)
        x+=1
        r,v,b=img.getpixel((x,y))
        n_r=255
        n_v=V
        n_b=b
        Img.putpixel((x,y),(n_r,n_v,n_b))
img.save("APhotoBleu.bmp")

# %% [markdown]
# Une fois que vous avez exécuter ce code, vous trouverez dans le dossier du volet de gauche un nouveau fichier image APhotoBleu.jpg, il vous suffit alors de double-cliquer dessus pour l'afficher.
# Vous devriez vous apercevoir que l'image n'a pas été intégralement modifiée et que la dominante de couleur n'est pas bleue.
#
# 2. Modifier le programme ci-dessus pour qu'il modifie bien **TOUS** les pixels de l'image en **BLEU**.
#
# 3. Enfin choisissez une image de votre choix et importez-la dans le dossier du volet de gauche. Puis copiez/collez le programme dans la cellule ci-dessous et modifiez-le pour que votre image soit convertie en niveau de gris.
#
# Principe du niveau de gris : il faut attribuer la même valeur à chaque canal d'un pixel. Communément on utilise le vert qui est la couleur que nous perçevons le plus à l'oeil nu !!!

# %%
"""
Vous pouvez tester votre programme de la question 3 dans cette cellule (après les 3 guillemets)...
"""
