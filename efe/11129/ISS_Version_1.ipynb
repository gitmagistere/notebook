# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99";>
# <div style="color:#ffffff;">
#
# # Qui est dans l'ISS ??
# </div>
#
#
# <span class="badge" style="color:#ffffff; background-color: #ee5555 ; font-size: 25px;"> SNT/NSI</span>

# %% [markdown]
# ## Exécuter la cellule suivante :

# %%
from IPython.display import HTML
HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/gUrcwDcRD3Y?si=rzm6E_mxobqPPqLS" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>""")
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/gUrcwDcRD3Y?si=rzm6E_mxobqPPqLS" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Web Service
# Un web service (ou service web) est une application ou un ensemble de fonctionnalités accessibles via Internet ou un réseau local, permettant à différentes applications, systèmes ou appareils de communiquer entre eux de manière standardisée et indépendante des plateformes.
#
# Un web service a une adresse (url) comme une page web. Au lieu de renvoyer du code HTML dans le cas d’une page web, il retourne des données.
#
# </div>

# %% [markdown]
# <h2 style="background-color: rgb(0,161,153); color: white; border-radius: 3px;padding: 10px;">✏️ Une activité</h2>
#
# <ol><li>Ouvrir le lien suivant : <a href="http://api.open-notify.org/astros.json">Exemple</a> </li>
# <li>Quel est le format de donnée enregistré dans cette page ?</li></ol>

# %% [markdown]
# <ol start="3"><li>Combien de personne sont actuellement dans l’espace ? <br></li></ol>

# %% [markdown]
# <ol start="4"><li>Comment s’appellent celles qui sont sur l'ISS ? </li></ol>

# %% [markdown]
# <ol start="5"><li>Ecrire un programme Python pour simuler le tirage aléatoire d'un nombre entre 1 et 9 </li></ol>

# %%
#votre code ici

# %% [markdown]
# <ol start="6"><li>Donner le nom de l'astronaute correspondant à votre tirage </li></ol>

# %%
from IPython.display import IFrame
IFrame(src="https://www.codepuzzle.io/PNHVL", width=800, height=500)

# %% [markdown]
# <div style="border-left:5px solid #ee5555; border-radius:2pt; color:#ffffff; padding:16px; background-color: #007f99">
#
# ## Pour aller plus loin
#
# </div>

# %% [markdown]
# # Intégrer un pdf

# %%
from IPython.display import IFrame
IFrame(src="https://www.sujetdebac.fr/annales-pdf/2023/spe-numerique-informatique-2023-metropole-2-sujet-officiel.pdf", width=900, height=500)
# Out:
# <iframe src="https://www.sujetdebac.fr/annales-pdf/2023/spe-numerique-informatique-2023-metropole-2-sujet-officiel.pdf" allowfullscreen="" width="900" height="500" frameborder="0"></iframe>

# %% [markdown]
# from IPython.display import HTML
# HTML("""<iframe width="560" height="315" src="https://www.youtube.com/embed/JiokX41_2nw?si=2THSNs37b5LiOuQx" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>""")
