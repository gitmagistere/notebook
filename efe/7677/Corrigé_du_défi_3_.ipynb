# %% [markdown]
# # Corrigé du défi 3

# %% [markdown]
# défi a)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[i,i]
    y=[0,10]
    plt.plot(x,y,color="k",lw=i)
plt.show()

# %% [markdown]
# défi b)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[0,10]
    y=[i,i]
    plt.plot(x,y,color="k",lw=i)
plt.show()

# %% [markdown]
# défi c)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[0,i]
    y=[i,0]
    plt.plot(x,y,color="k",lw=i)
plt.show()

# %% [markdown]
# défi d)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[i,10]
    y=[0,10-i]
    plt.plot(x,y,color="k",lw=i)
plt.show()

# %% [markdown]
# défi 1)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[i,10]
    y=[0,i]
    plt.plot(x,y,color="k",lw=1)
plt.show()

# %% [markdown]
# défi 2)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[i,10-i]
    y=[i,i]
    plt.plot(x,y,color="k",lw=1)
plt.show()

# %% [markdown]
# défi 3)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(10):
    x=[0,10-i]
    y=[0,i]
    plt.plot(x,y,color="k",lw=1)
plt.show()

# %% [markdown]
# défi 4)

# %%
from matplotlib import pyplot as plt

plt.axis([0,10,0,10])

for i in range(5):
    x=[i,10-i,10-i,i,i]
    y=[i,i,10-i,10-i,i]
    plt.plot(x,y,color="k",lw=i)
plt.show()
