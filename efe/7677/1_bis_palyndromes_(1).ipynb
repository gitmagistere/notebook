# %% [markdown]
# # PALINDROMES

# %% [markdown]
# Dans cet exercice, nous allons travailler sur un fichier "txt" contenant le dictionnaire français. Nous travaillerons donc sur des chaines de caractères (type str). Une boîte à outils en bas de document rappelle les principales méthodes relatives aux chaines de caractères.

# %%
import pandas as pd   
# import de pandas avec pour alias pd

url = 'http://perpendiculaire.fr/data/mots.txt'

df = pd.read_csv(url,sep=' ')
# on importe le dictionnaire au format txt , l'espace est le séparateur de données

# %% [markdown]
# 1. Exécuter la cellule ci-dessus, puis éxécuter la commande ci-dessous :

# %%
df.head(10)
# Out:
#       MOTSDICO
# 0            a
# 1            à
# 2      abaissa
# 3   abaissable
# 4  abaissables
# 5     abaissai
# 6  abaissaient
# 7    abaissais
# 8    abaissait
# 9   abaissâmes

# %% [markdown]
# 2. Exécuter la cellule ci-dessous et en déduire le nombre de mots dans le dictionnaire.

# %%
df.shape
# Out:
# (336531, 1)

# %% [markdown]
# 3. Sans utiliser le code, prédire ce que renvoie l'appel df[ 'MOTSDICO' ][ 6 ]. Vérifier ensuite ci-dessous :

# %% [markdown]
# 4. Compléter la fonction motinverse(motsaisi) qui prend en paramètre une chaine de caractères nommée "motsaisi" et renvoie le mot inversé.
#
# (aide :la boucle for lettre in "bonjour": parcourt chaque caractère du mot bonjour)

# %%
def motinverse(motsaisi):
    motinverse = "" 
    for lettre in motsaisi:

# %% [markdown]
# 5. Vérifier votre travail en éxécutant la cellule ci-dessous :

# %%
motinverse("AZERTY")

# %% [markdown]
# 6. Ecrire une fonction palindrome qui prend en paramètre une chaine de caractères et renvoie True si le mot est un palindrome, False sinon.

# %%
def palindrome(mot):

# %% [markdown]
# 7. Tester votre travail ci-dessous :

# %%
palindrome("RADAR")

# %% [markdown]
# 8. Compléter le programme permettant de rechercher les palindromes du dictionnaire français à l'aide d'une boucle et de les afficher dans une liste.

# %%
palindromes = []

for i in range(336530):
  mot = df['MOTSDICO'][i]
  
  

palindromes

# %% [markdown]
# 9.  Compléter le programme pour qu'il affiche la longueur de chaque palindrome de la liste.

# %%
for pal in ...

# %% [markdown]
# 10. Réaliser un programme permettant d'obtenir une liste nommée "effectifs". Cette liste donnera le nombre de palindromes de longueur 1, 2, 3 ... 9.

# %%
effectifs = [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %% [markdown]
# 11. Réalisons un diagramme en bâtons indiquant le nombre de palindrômes ayant une longueur donnée.

# %%
import matplotlib.pyplot as plt

longueurs = [1, 2, 3, 4, 5, 6, 7, 8, 9]

width = 0.5

plt.bar(longueurs, effectifs, width, color='b' )

plt.show()

# %% [markdown]
# ![outilschaines.png](data:image/png;base64,...)
