# %% [markdown]
# <img src="https://www.ac-aix-marseille.fr/sites/ac_aix_marseille/files/site_logo/2021-01/logo_AC_AIX%20MARSEILLE_REC.jpg" width="150px" ></img>
#
# Ce fichier vous est présenté par le groupe académique Mathice d'Aix-Marseille.<br/>
# Inspecteur chargé du groupe : M. Christophe Mazuyer, christophe.mazuyer@ac-aix-marseille.fr. <br/>
# IAN Mathématiques : M. Jean-Baptiste Civet, jean-baptiste.civet@ac-aix-marseille.fr. <br/>
# Auteur du fichier : M. Alexandre Colin, alexandre-jean.colin@ac-aix-marseille.fr.  <br/>
# Public visé : Enseignants. Rapidement transférable avec des élèves.<br/>
#
# **Ce document n'est pas destiné à être un support pédagogique pour les élèves mais constitue un support de formation à destination des enseignants. Il s'inscrit dans le cadre d'un parcours en présentiel / distanciel (PAF).**
#
# Activité 1, code 2193-571331 : Python, une calculatrice
# Activité 2, code 2500-571332 : Faire des fonctions
# Activité 3, code 9fb3-571335 : Les modules
# Activité 4, code 7ae9-571337 : les instructions conditionnelles
# Activité 5, code 9a07-571339 : les boucles bornées
# Activité 6, code e60b-571340 : les boucles non bornées
# Activité 7, code 0e04-609566 : les listes, non transférable aux élèves

# %% [markdown]
# # <p style="text-align:center;"> Formation Python Débutant - Les opérations de base en Python</p>
#
# **Objectif :**
# - Découvrir l'environnement Capytale et des carnets Jupyter.
# - Découvrir quelques opérations mathématiques en Python, notamment l'écriture de la puissance et les opérations de division euclidienne.
# - Découvrir l'affectation d'un résultat, la notion de variable et son affichage.
#
#
# ## Focus sur les carnets Jupyter
#
# Vous êtes actuellement en train de lire ce que l'on appelle un <b>carnet Jupyter</b> : c'est un ensemble de cellule qui peuvent contenir :
# - du texte ;
# - du code informatique écrit avec Python :
#     - dans un format "console" (à la suite de >>> dans un interpréteur classique) : en général, on fait les opérations une par une dans la console.
#     - dans un format "script".
#
# On va alterner ces trois types de contenu dans la formation. Dans un premier temps, on va bien indiquer, pour Python, de quel type est la cellule. On va donc écrire un commentaire sous Python, avec un #.
#
# Regardez rapidement la barre de menu que vous avez pour y trouver les deux principales commandes :
# - une petite disquette pour enregistrer votre travail ;
# - un bouton avec une flèche indiquant "Exécuter" : cela vous permet d'exécuter le code d'une cellule.
#
# Il faudra prendre soin :
# - d'enregistrer régulièrement votre travail
# - d'éxécuter chaque cellule de code au fur et à mesure.
#
#
# ## Les opérations mathématiques de base en Python
#
# Il existe un certain nombre d'opérations mathématiques dont nous avons besoin en algorithmique pour débuter :
# - l'addition : +
# - la soustraction : -
# - la multiplication : *
# - la division : /
# - la puissance : **
#
# Essayez les opérations en exécutant les cellules ci-dessous :

# %%
# C'est une opération que l'on fait en console normalement :
4+5

# %%
# C'est une opération que l'on fait en console normalement :
4-5

# %%
# C'est une opération que l'on fait en console normalement :
4*5

# %%
# C'est une opération que l'on fait en console normalement :
4/5

# %%
# C'est une opération que l'on fait en console normalement :
4**5

# %% [markdown]
# !!! example <p style="color:red;"> A vous de faire : </p>
# Réaliser le calcul suivant sur la cellule ci-dessous : $(\frac{9 \times 8}{6}-10)^5$.<br/>
# Vous devez trouver 32.
# !!!

# %%
# C'est une opération que l'on fait en console normalement :

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
# ```python
# (9*8/6-10)**5
# ```
#
# </details>
# !!!

# %% [markdown]
# ## Autour de la division euclidienne
#
# #### Définition
#
# En programmation, on travaille la plupart du temps avec des entiers. On ne fait pas de division, mais une division euclidienne : la division euclidienne de $a$ par $b$ revient à trouver les réels $q$ et $r$ tels que l'on ait<br/>
# $$a = b \times q +r$$
# $$0 \leq r < b$$ <br/>
# Le nombre $q$, appelé quotient, est donné par la commande Python : a//b.<br/>
# Le nombre $r$, appelé reste, est donné par la commande Python : a%b.<br/>
# Par exemple, pour obtenir le quotient et le reste dans la division euclidienne de 25 par 4 :

# %%
# C'est une opération que l'on fait en console normalement :
25//4

# %%
# C'est une opération que l'on fait en console normalement :
25%4

# %% [markdown]
# La division euclidienne permet de répondre à la question : dans 100, combien de fois rentre-t-il 6 ?

# %%
# C'est une opération que l'on fait en console normalement :
100//6

# %% [markdown]
# et alors, combien il reste ?

# %%
# C'est une opération que l'on fait en console normalement :
100%6

# %% [markdown]
# !!! example <p style="color:red;"> A vous de faire : </p>
# Quel est le quotient de la division euclidienne de 125 par 7 ?
# !!!

# %%
# C'est une opération que l'on fait en console normalement :

# %% [markdown]
# Quel est le reste de la division euclidienne de 125 par 7 ?

# %%
# C'est une opération que l'on fait en console normalement :

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
# ```python
# 125//7
# 125%7
# ```
#
# </details>
# !!!

# %% [markdown]
# #### Application à la parité d'un nombre
#
# La division euclidienne permet aussi de savoir si un nombre est pair ou impair : il suffit de regarder si le reste dans la division euclidienne par 2 est 0 (nombre pair) ou 1 (nombre impair).
# C'est une fonctionnalité qui est très utile dans de très nombreux programmes.
#
# Vérifions que 13 est bien impair :

# %%
# C'est une opération que l'on fait en console normalement :
13%2

# %% [markdown]
# !!! example <p style="color:red;"> A vous de faire : </p>
# $2021^{2021}+1$ est-il :
#
# - pair ou impair ?
# - un multiple de $3$ ?
# !!!

# %%
# C'est une opération que l'on fait en console normalement :

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
# ```python
# (2021**2021+1) % 2
# (2021**2021+1) % 3
# ```
#
# </details>
# !!!

# %% [markdown]
# #### Application à la recherche du nombre de chiffres d'un nombre.
#
# La division euclidienne permet aussi de déterminer le nombre de chiffres que possède un nombre.
# Nous allons dans un premier temps travailler "à tâtons" avec le nombre 123 456 789 : en quoi les résultats suivants nous permettent-ils de dire que le nombre de chiffres de ce nombre est 9 ?

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**2

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**3

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**4

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**5

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**6

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**7

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**8

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**9

# %%
# C'est une opération que l'on fait en console normalement :
123456789//10**10

# %% [markdown]
# !!! example <p style="color:red;"> A vous de faire : </p>
# En travaillant "à tâtons", déterminer le nombre de chiffres que possède $2022^{2022}$.
# !!!

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
#     (2022**2022) // (10**6684) a pour valeur 1 et (2022**2022) // (10**6685) a pour valeur 0. Notre nombre possède donc 6685 chiffres.
#
# </details>
# !!!

# %% [markdown]
# ## L'affectation `=`
#
# L'affectation dans une variable se fait simplement avec le signe `=`. Le nom de la variable peut contenir des lettres en minuscule, majuscule, des chiffres (mais il ne peut pas commencer par un chiffre) et le caractère `_`.
# Nous vous recommandons d'utiliser des noms qui ont du sens, même s'ils sont très longs : vous éviterez ainsi les mots anglais du langage Python.
# **L'affectation n'est pas un affichage : le fait d'affecter ne génére pas d'affichage.** *Par contre*, si j'appelle la variable, je pourrais avoir un affichage.

# %%
# C'est une opération que l'on fait en console normalement :
annee_courante = 2022

# %%
# C'est une opération que l'on fait en console normalement :
annee_courante

# %%
# C'est une opération que l'on fait en console normalement :
exemple1 = 7**2

# %%
# C'est une opération que l'on fait en console normalement :
exemple1

# %%
# C'est une opération que l'on fait en console normalement :
je_veux_faire_un_nom_de_variable_très_long = 12//3

# %%
# C'est une opération que l'on fait en console normalement :
je_veux_faire_un_nom_de_variable_très_long

# %% [markdown]
# La lecture se fait de "droite à gauche" :
# - j'affecte le nombre 2022 à la variable `annee_courante`
# - j'affecte le résultat de $7^2$ à la variable `exemple1`
# - j'affecte le résultat du quotient de la division euclidienne de 12 par 3 à la variable `je_veux_faire_un_nom_de_variable_très_long`.
#
# Il faut donc bien avoir en tête que l'on réalise déjà le calcul qui est à droite, puis qu'on affecte ce résultat dans le nom de variable présent à gauche. Cela signifie que l'on peut alors **écraser** le contenu d'une variable par un autre.

# %%
# C'est une opération que l'on fait en console normalement :
annee_suivante = annee_courante + 1

# %%
# C'est une opération que l'on fait en console normalement :
annee_suivante

# %%
# C'est une opération que l'on fait en console normalement :
nnee_suivante = annee_suivante + 1

# %%
# C'est une opération que l'on fait en console normalement :
annee_suivante

# %% [markdown]
# ## La fonction `print()`
#
# Python est un langage de programmation international. Les noms de ces fonctions sont donc des noms anglais. `print()` permet de faire l'affichage d'une variable :

# %%
# C'est une opération que l'on fait en console normalement :
print(annee_courante)

# %% [markdown]
# La fonction `print` peut prendre plusieurs paramètres :

# %%
# C'est une opération que l'on fait en console normalement :
print(annee_courante, exemple1)

# %% [markdown]
# La fonction `print` peut combiner du texte et des variables.

# %%
# 1ere méthode
print("Nous sommes dans l'année",annee_courante)
# 2eme méthode
print(f"C'est l'année {annee_courante} !")

# %% [markdown]
# !!! question Information
# La deuxième méthode est une *bonne pratique d'informaticien*, appelée `f-string`. Mais ce n'est pas celle qui doit être mise en avant en mathématique.
# ```print``` n'est pas à utiliser en console, à moins de vouloir faire une "belle phrase". Par contre, il peut avoir une utilité dans un script pour afficher les résultats directement en lançant le script.
# !!!
#
# !!! warning **Un premier exemple d'erreur :**
# !!!

# %%
print(b)

# %% [markdown]
# Ce bloc nous affiche une erreur. Lors de l'affichage de l'erreur, il y a deux choses qui vont nous intéresser :
# - la ligne à laquelle l'erreur est apparue : ici, c'est la ligne 1 (`line 1`) ;
# - le nom de l'erreur : `NameError : name 'b' is not defined`
#
# Là encore, on est sur de l'anglais, mais cela reste de **l'anglais abordable** : le nom de variable `b` n'est pas défini. Donc Python ne sait pas quoi faire avec `b`...

# %% [markdown]
# !!! example <p style="color:red;"> A vous de faire : exercice de synthèse </p>
#
# On s'intéresse au programme de calcul suivant : <br/>
# - Choisir un nombre ; <br/>
# - Multiplier ce nombre par 2 ;<br/>
# - Ajouter 5 au résultat ;<br/>
# - Multiplier votre résultat par votre nombre de départ.<br/>
#
# Ecrire ce programme de calcul lorsque le `nombre_choisi` est 2022 et afficher le résultat.
# !!!

# %%
# Pour écrire un programme de calcul, comme il y a plusieurs étapes, je vais toutes les taper dans la même cellule :
# j'utilise alors le Classeur (notebook) non plus comme une console mais comme un script.

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
#     Une première réponse en "étape par étape". Les noms de variable pourrait d'ailleurs être etape1, etape2, ... C'est la méthode à utiliser lors de première rencontre avec des élèves.
#
# ```python
# nombre_choisi = 2022
# resultat = nombre_choisi * 2
# resultat = resultat + 5
# resultat = resultat * nombre_choisi
# print(resultat)
# ```
#
#     Une deuxième réponse, en écrivant toutes les étapes en une seule. C'est la méthode vers laquelle on vise lorsque les élèves sont à l'aise en algorithmique.
#
# ```python
# nombre_choisi = 2022
# resultat = (nombre_choisi * 2 + 5) * nombre_choisi
# print(resultat)
# ```
#
# </details>
# !!!
