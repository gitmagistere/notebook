# %% [markdown]
# <img src="https://www.ac-aix-marseille.fr/sites/ac_aix_marseille/files/site_logo/2021-01/logo_AC_AIX%20MARSEILLE_REC.jpg" width="150px" ></img>
#
# Ce fichier vous est présenté par le groupe académique Mathice d'Aix-Marseille.<br/>
# Inspecteur chargé du groupe : M. Christophe Mazuyer, christophe.mazuyer@ac-aix-marseille.fr. <br/>
# IAN Mathématiques : M. Jean-Baptiste Civet, jean-baptiste.civet@ac-aix-marseille.fr. <br/>
# Auteur du fichier : M. Alexandre Colin, alexandre-jean.colin@ac-aix-marseille.fr.  <br/>
# Public visé : Enseignants. Rapidement transférable avec des élèves.<br/>
#
# **Ce document n'est pas destiné à être un support pédagogique pour les élèves mais constitue un support de formation à destination des enseignants. Il s'inscrit dans le cadre d'un parcours en présentiel / distanciel (PAF).**
#
# Activité 1, code 2193-571331 : Python, une calculatrice
# Activité 2, code 2500-571332 : Faire des fonctions
# Activité 3, code 9fb3-571335 : Les modules
# Activité 4, code 7ae9-571337 : les instructions conditionnelles
# Activité 5, code 9a07-571339 : les boucles bornées
# Activité 6, code e60b-571340 : les boucles non bornées
# Activité 7, code 0e04-609566 : les listes, non transférable aux élèves

# %% [markdown]
# # <p style="text-align:center;"> Formation Python Débutant - Les instructions conditionnelles</p>
#
# ### Les tests
#
# On a très souvent besoin d'écrire des conditions en mathématique et informatique : si... alors ... <br/>
# On peut réaliser différents tests en Python :
# - l'égalité : `==`
# - l'inégalité : `!=`
# - strictement inférieur : `<`
# - inférieur ou égal : `<=`
# - strictement supérieur : `>`
# - supérieur ou égal : `>=`
# - l'appartenance à un ensemble : `in`
# - la non-appartenance à un ensemble : `not in`<br/>
#
#
# La réponse à une condition est un <b>booléen</b> : `True` ou `False` (avec une majuscule, c'est un mot clé de Python)
#
# Regardez les exemples ci-dessous :

# %%
# C'est une opération que l'on fait en console normalement :
2 == 3

# %%
# C'est une opération que l'on fait en console normalement :
2 != 3

# %%
# C'est une opération que l'on fait en console normalement :
2 < 3

# %%
# C'est une opération que l'on fait en console normalement :
2 <= 3

# %%
# C'est une opération que l'on fait en console normalement :
2 > 3

# %%
# C'est une opération que l'on fait en console normalement :
2 >= 3

# %%
# C'est une opération que l'on fait en console normalement :
2 in [2,3,4]

# %%
# C'est une opération que l'on fait en console normalement :
2 not in [2,3,4]

# %% [markdown]
# Muni de ces différentes conditions, on peut maintenant réaliser des fonctions plus complexes :

# %%
def est_pair(n):
    "Indique si un entier est pair"
    return n%2 == 0

est_pair(2022**2022)
# Out:
# True

# %%
def est_triangle_rectangle(a,b,c):
    "Indique si le triangle de côtés a,b,c avec c le plus long côté est rectangle"
    return a**2 + b**2 == c**2

est_triangle_rectangle(3,4,5)
# Out:
# True

# %% [markdown]
# !!! example <p style="color:red;">A vous de faire :</p>
#
# Définir une fonction `est_multiple_5` qui possède un paramètre `n` et qui indique si `n` est un multiple de 5.
# !!!

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
# ```python
# def est_multiple_5(n):
#     return n%5 == 0
# ```
#
# </details>
# !!!

# %% [markdown]
# ### Les structures conditionnelles
#
# <p style="color:green;font-size:1.3em;"> <u><b>Définition</b></u> :
#     En <i>informatique</i>, on appelle <b>structure conditionnelle</b> les instructions qui permettent de tester si une condition est vraie ou non. <br/>
#     L'instruction <u>if</u> est la structure de test la plus basique : elle permet d'exécuter une série d'instructions si une condition est vraie.
# </p>
#
# Les mots clés de Python sont en anglais, notre "si" va donc devenir un `if`, "ou si" se traduit par `elif` et "sinon" par `else`.
# L'indentation va permettre de savoir si l'on est dans la structure conditionnelle ou non. Chaque ligne comportant une structure conditionnelle se termine par deux points `:`.
# ```
# if condition1:
#     si le test conditionnel renvoie Vrai, faire ceci
# elif condition2:
#     si le test conditionnel renvoie Vrai, faire cela
# else:
#     sinon, faire autre chose
# ```
#
# On fera attention au pléonasme de programmation :
# ```
# def egalité(a,b):
#     "Test l'égalité entre a et b"
#     if a == b:
#         return True
#     else:
#         return False
# ```
#
# correspond au même code que :
#
# ```
# def egalité(a,b):
#     "Test l'égalité entre a et b"
#     return a == b
# ```

# %% [markdown]
# Regardons des exemples concrets : <br/>
# <u>Exemple 1 :</u> <br/>
# Dans un atelier de reprographie, la photocopie est à 0,10 euro.<br/>
# Mais pour plus de 20 photocopies, le prix unitaire est de 0,08 euro.<br/>
# La fonction ci-dessous donne le prix à payer en fonction du nombre de photocopies :

# %%
def prix_à_payer(nb_photocopies):
    if nb_photocopies <= 20:
        return 0.10*nb_photocopies
    else:
        return 0.08*nb_photocopies
    
print("Le prix à payer pour 15 photocopies est de : ",prix_à_payer(15))
print("Le prix à payer pour 100 photocopies est de : ",prix_à_payer(100))

# %% [markdown]
# <u>Exemple 2 :</u>

# %%
from math import sqrt

def mystère(x):
    if x < -2:
        return -2*x + 1
    elif -2 <= x < 4:
        return x**2 + 1
    else:
        return sqrt(x) + 15

# %% [markdown]
# Pouvez-vous dire ce que renvoie :
# - mystère(-5) ?
# - mystère(16) ?
# - mystère(3) ?
#
# <i>Vous pouvez utiliser la cellule de code ci-dessous si besoin pour tester la fonction.</i>

# %% [markdown]
# !!! example <p style="color:red;">A vous de faire :</p>
#
# Compléter la fonction `maximum` qui possède deux paramètres `a` et `b` et qui renvoie le plus grand des deux nombres.
# !!!

# %%
def maximum(a,b):
    "Fonction qui renvoie le maximum des deux nombres a et b"
    if ...:
        return a
    else:
        return ...
    
print("Le plus grand entre 3 et 5 est : ",maximum(3,5))
# Out:
# Le plus grand entre 3 et 5 est : {maximum(3,5)}

# %% [markdown]
# !!! example Utiliser cette fonction pour déterminer le maximum entre $2\sqrt{3}$ et $3\sqrt{2}$.
# !!!

# %%
from math import ...
print(...)

# %% [markdown]
# !!! example <p style="color:red;">A vous de faire :</p>
#
# Le prix d'un billet de car est le suivant :
# - 13 euros pour les jeunes (moins de 18 ans) et les seniors (plus de 60 ans) qui achètent au moins 4 tickets
# - 15 euros pour les seniors qui achètent moins de 4 tickets
# - 17 euros dans tous les autres cas.
#
# Compléter la fonction `prix_total` qui possède deux paramètres `age` et `nbre_ticket` et qui renvoie le prix à payer.
# !!!

# %%
def prix_total(age, nbre_ticket):
    if nbre_ticket >= ... and age <=...:
        return nbre_ticket * 13
    elif nbre_ticket >= ... and age >=...:
        return nbre_ticket * 13
    elif age >= 60:
        return ...
    else:
        return ...
    
print("J'ai 15 ans et je veux 5 tickets, je dois payer : ",prix_total(15,5))

# %% [markdown]
# !!! example <p style="color:red;">A vous de faire :</p>
# 1. Ecrire une fonction qui renvoie le maximum de 2 nombres.
# 2. Ecrire une fonction qui renvoie le maximum de 3 nombres.
# 3. Ecrire une fonction qui indique si l'on peut construire un triangle de longueurs a, b, c (données dans n'importe quel ordre).
# 4. Ecrire une fonction qui indique si un nombre est un multiple de 3 ou de 5 mais pas de 3 et de 5.
# 5. Ecrire une fonction qui indique si une année est bissextile (multiple de 4, multiple de 400, non multiple de 100).
# 6. Ecrire une fonction qui indique le nombre de jours d'un mois (31 jour pour le mois 0, 28 jours pour le mois 1, ...) et qui peut prendre en compte les années bissextiles.
# 7. Ecrire une fonction qui indique si deux vecteurs sont colinéaires ou si deux droites sont parallèles.
# !!!

# %% [markdown]
# !!! success La réponse
# <details>
#     <summary style="color:red;">&rarr;Cliquez-ici pour la réponse&larr; </summary>
#
# ```python
# def maximum_deux_nombres(a,b):
#     if a>b:
#         return a
#     else:
#         return b
#
# def maximum_trois_nombres(a,b,c):
#     "On peut fonctionner sans else."
#     if a>b and a>c:
#         return a
#     elif b>a and b>c:
#         return b
#     return c
#
# def est_triangle_construtible(a,b,c):
#     return a>b+c or b>a+c or c>a+b
#
# def est_multiple_de_3_ou_5(a):
#     if a%3 == 0:
#         return a%5 != 0
#     elif a%5 == 0:
#         return a%3 != 0
#     return False
#
# def est_annee_bissextile(a):
#     if a%400 == 0:
#         return True
#     elif a%100 == 0:
#         return False
#     elif a%4 == 0:
#         return True
#     return False
#
# def nbre_jours(mois, annee):
#     if mois == 1:
#         if est_annee_bissextile(annee) == True:
#             return 29
#         return 28
#     if mois <= 6:
#         return 30 + (mois+1)%2
#     else:
#         return 30 + mois%2
#
# def vecteurs_colineaires(Xu,Yu,Xv,Yv):
#     return Xu * Yv - Xv * Yu == 0
# ```
#
#
# </details>
# !!!

# %% [markdown]
# # Remarque importante sur les tests d'égalités
#
#
# !!! warning Python doit, comme tous les programmes de programmation, stocker les nombres décimaux sous forme binaire. Or ce n'est pas facile ! Et cela amène donc à des erreurs... Regardons l'erreur ci-dessous :
# !!!

# %%
print(0.1 + 0.1 + 0.1 == 0.3)

# %% [markdown]
# !!! success Ainsi les tests d'égalités peuvent être défectueux sur certaines valeurs bien choisies. On fera donc attention de travailler le plus souvent avec des entiers et des divisions euclidiennes, ou de modifier éventuellement légérement les tests (mais qui pourront toujours être mis à mal si l'on choisi bien les valeurs pour *planter* l'algorithme).
# !!!

# %%
print(0.1 + 0.1 + 0.1 - 0.3 < 10**(-16))
