# %% [markdown]
# <div style="padding:5px; border-radius:10px;background-color:lightsalmon;">
# <h1 style="text-align:center;color:black;"> TP Tuples et dictionnaires</h1>
# <h3 style="text-align:center;"> 1 NSI</h3>
# <h4 style="text-align:center;"> MB  </h4>
# </div>

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;"> Exercice n°1 : Les tuples</h2>

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# 1.En utilisant les tuples pour les coordonnées x,y de points dans un répère
# du plan, créer une fonction qui calcule la distance entre deux points d'un
# repère orthonormé.</div>

# %%
from math import sqrt
def distance(u,v):
    pass

print(distance((4,5),(2,3)))

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# 2. Avec des tuples de tuples qui contiennent le prénom et l'âge de plusieurs
# personnes, faire afficher 'bonjour Alim tu as 17 ans', et ainsi de suite pour
# les autres.</div>

# %%
gens=(("Alice",12),("Bob",13),("Charles",16))
...

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
#     3. Les commandes <code>sum(tuple),len,min,max</code> donnent respectivement la
# somme, le nombre d'éléments, le min et le max d'un tuple. Ecrire une
# fonction qui renvoie le tuple composé du min, max, moyenne.</div>

# %%
tuple=(2,3,5,78)
def calculs(t):
    pass


print(calculs(tuple))

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;">Exercice n°2 : dictionnaires </h2>

# %% [markdown]
# On considère le dictionnaire suivant, correspondant au nombre de points
# d'une lettre au scrabble (pour les 9 premières lettres de l'alphabet) :

# %%
"""dictionnaire du comptage des points au scrabble"""
scrabble={'A':1,'B':3,'C':3,'D':2,'E':1,'F':4,'G':2,'H':4,'I':1,'J':8,'K':10,'L':1,'M':2,'N':1,'O':1,'P':3,'Q':8,'R':1,'S':1,'T':1,'U':1,'V':4,'W':10,'X':10,'Y':10,'Z':10}

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">Ecrire une fontion qui prend en paramètre un mot et qui calcule et renvoie le nombre de points réalisés par un mot.<br>
#     <code>Compte_Scrabble('BACHE')</code> doit renvoyer 12.
# </div>

# %%
def Compte_Scrabble(mot):
    pass
print(Compte_Scrabble('BACHE'))

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;">Exercice n°3 : dictionnaires de tuples </h2>

# %%
exemple_pokemon ={'Bulbizarre':(70,7),'Herbizarre':(100,13)}

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">1. Quel est le type de la variable <code>exemple_pokemon</code>
# </div>

# %%
...

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Ajouter à cette structure de données le
# pokémon Goupix qui mesure 60 cm et pèse 10 kg ?</div>

# %%
...

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# On donne le code suivant. Que fait-il?</div>

# %%
def fonction_mystere(dico):
    valeur1=0
    valeur2=0
    for (nom,(taille,poids)) in dico.items():
        if valeur1==0 or taille>valeur1:
            valeur1=taille
            valeur2=nom
    return(valeur2,valeur1)
fonction_mystere(exemple_pokemon)

# %% [markdown]
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Écrire une fonction <code>le_plus_leger</code> qui prend exemple_pokemons en
# paramètre et qui renvoie un tuple dont la 1e composante est le nom du
# pokémon et la 2 e est son sa masse.</div>

# %%
def le_plus_leger(dico):
    pass


print(le_plus_leger(exemple_pokemon))

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">
# Écrire une fonction <code>taille</code> qui prend en paramètre un nom de
# pokémons et exemple_pokemons et qui renvoie la taille de ce
# pokémon.</div>

# %%
def taille(nompok,dico):
    pass
print(taille('Goupix',exemple_pokemon))

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">Écrire une fonction qui calcule la somme totale des poids de tous les
# pokémons du dictionnaire proposé.</div>

# %%
def somme_poids(dico):
    pass

print(somme_poids(exemple_pokemon))

# %% [markdown]
# <h2 style="color: orange; font-style: 16px italic verdana;">Exercice n°4 : jeu de construction </h2>

# %% [markdown]
# On représente un jeu de construction par un dictionnaire de la façon suivante :

# %%
"""dictionnaire jeu de construction"""
Jeu={('cube', 'noir'): 21, ('cube', 'bleu'): 16, ('cube', 'jaune'): 23, ('cube', 'vert'): 30, ('cube', 'blanc'): 26, ('cube', 'rose'): 18, ('cube', 'rouge'): 18, ('pavé', 'noir'): 25, ('pavé', 'bleu'): 26, ('pavé', 'jaune'): 26, ('pavé', 'vert'): 27, ('pavé', 'blanc'): 23, ('pavé', 'rose'): 22, ('pavé', 'rouge'): 29, ('boule', 'noir'): 26, ('boule', 'bleu'): 29, ('boule', 'jaune'): 27, ('boule', 'vert'): 27, ('boule', 'blanc'): 22, ('boule', 'rose'): 19, ('boule', 'rouge'): 21, ('prisme', 'noir'): 15, ('prisme', 'bleu'): 25, ('prisme', 'jaune'): 19, ('prisme', 'vert'): 25, ('prisme', 'blanc'): 27, ('prisme', 'rose'): 29, ('prisme', 'rouge'): 22, ('pyramide', 'noir'): 21, ('pyramide', 'bleu'): 20, ('pyramide', 'jaune'): 16, ('pyramide', 'vert'): 26, ('pyramide', 'blanc'): 30, ('pyramide', 'rose'): 17, ('pyramide', 'rouge'): 15, ('cone', 'noir'): 27, ('cone', 'bleu'): 23, ('cone', 'jaune'): 17, ('cone', 'vert'): 27, ('cone', 'blanc'): 24, ('cone', 'rose'): 15, ('cone', 'rouge'): 26}

# %% [markdown]
# Que l'on interprète de la façon suivante : il y a 31 cubes bleus dans le jeu.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">1. Écrire une fonction qui prend en paramètre le dictionnaire et une forme (par exemple cube) et qui affiche le nombre d'objets de cette forme.
# </div>

# %%
def nb_forme(f,dico):
    pass

print(nb_forme("cube",Jeu))

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">2. Écrire une fonction qui prend en paramètre le dictionnaire et une couleur et qui affiche le nombre d'objets de cette couleur.
# </div>

# %%
def nb_couleur(c,dico):
    pass


print(nb_couleur("jaune",Jeu))

# %% [markdown]
# <div class="alert alert-success" style="border-left: 5px solid #3c763d;border-radius:2px;">3. Écrire une fonction qui prend en paramètre le dictionnaire et qui affiche le nombre total d'objets du jeu.
# </div>

# %%
def nb_pieces(dico):
    pass

print(nb_pieces(Jeu))
