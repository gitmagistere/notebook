# %% [markdown]
# # Première étape
# Ouvrir le document PDF contenant les consignes (depuis M@gistère).
# Téléchargez le fichier csv depuis M@gistere et importez le dans Basthon

# %%
import folium
import pandas as pd
