# %%
# modelisation de l'avancement de la réaction de combustion de l'éthanol
# dans le dioxygène.


nO2i = 25
nC2H6Oi = 8

###########################################
#         partie I : input et print       #
###########################################


# le programme doit demander quelle est la quantité de matière initiale de dioxygène
# et la stocker dans la variable numérique nO2i


# il doit demander la quantité de matière initiale d'éthanol et stocker cette valeur
# dans la variable numérique nC2H6Oi

# Le programme doit afficher les quantités de matière initiale pour verification par l'utilisateur
# par exemple, afficher le texte " le Chimiste a fait réagir x mol de dioxygène et y mol d'éthanol "



##########################################
#        partie II : if, else, elif      #
##########################################

x1 = nO2i/3
x2 = nC2H6Oi/1

# Determination du réactif limitant

# Vous devez remplacer les ????????? par l'éthanol , le dioxygène ou les deux

if x1<x2 :
    xmax = x1
    Rlimitant = "?????????"   # nom du réactif à completer

elif x1>x2 :
    xmax = x2
    Rlimitant = "????????"

else :
    xmax = x1
    Rlimitant = "?????????"


#affichage du résultat
if Rlimitant =='les deux' :
    print('les deux réactifs sont limitants, nous sommes dans les conditions stoechiométriques, xmax vaut ',round(xmax,1),' mol')
else :
    print('le réactif limitant est ',Rlimitant,'et xmax vaut',round(xmax,1),' mol')
    # round arrondi la valeur de xmax a 1 chiffre après la virgule
