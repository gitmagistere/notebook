# %%
nombre = float(input('Entrez un nombre entre 1 et 100 : '))

if nombre <= 0 :
    print('Vous ne respectez pas la consigne !')
elif nombre > 100 :
    print('Vous ne respestez pas la consigne !')
elif nombre < 50 :
    print('Vous avez entré un nombre inférieur à 50')
elif nombre > 50:
    print('Vous avez entré un nombre supérieur à 50')
else :
    print('Vous avez entré 50')
