# %% [markdown]
# # Activité à réaliser
#
# 1. Exécuter le script de la cellule ci-dessous en cliquant sur le bouton d'exécution en forme de flèche ou la combianaison de touches CTRL + ENTREE.
# 2. Modifier le script et exécuter à nouveau pour observer les changements.

# %%
a = 3
b = 4* a + 2
print(a)
print(b)

# %% [markdown]
# L'interpréteur va d'abord évaluer (lire et calculer) ce qu'il y a à droite du signe égal puis l'affecter à la case mémoire référencée à gauche. Si la case mémoire n'existe pas, elle est créée.
# Si elle existe, sa valeur est effacée et remplacée par le nouvelle valeur.
#
# Ainsi, la ligne `i = i + 1` est tout à fait correcte et le `i` à gauche du signe égal est différent du `i` à droite du signe égal.
#
# Par exemple:

# %%
i = 0
print( i )
i = i + 1
print( i )

# %% [markdown]
# Python permet de faire des affectations "simultanées" et ainsi inverser le contenu de deux variables en une seule ligne:

# %%
a = 10
b = 3
print(a, b)
a, b = b, a
print(a, b)

# %% [markdown]
# Sans cela, il serait nécessaire d'utiliser une troisième variable pour ne pas perdre d'information.

# %%
a = 10
b = 3
print(a, b)
c = a
a = b
b = c
print(a, b)

# %% [markdown]
# # Activité à réaliser
#
# Modifier les valeurs dans la cellule ci-dessous et observer le résultat affiché.

# %%
# initialiser les variables
a = 2
b = 3 - a
# afficher les variables
print(a, b)

# %% [markdown]
# # Important
#
# Vous ne pouvez affecter une valeur qu'à une variable et pas à une expression, ainsi les écritures suivantes ne sont pas correctes!
#
# a + b = 6
#
# cos(x) = -1

# %%
a + b = 6

# %%
cos(x) = -1
