# %% [markdown]
# 1)	Calcul du volume V d’un cylindre de rayon r et de hauteur h.
#         Exécuter ce programme avec r = 2 et h = 4 (les dimensions sont en cm)

# %%
from math import*
def V(r,h):
    return pi*r**2*h
r=float(input("rayon ?"))
h=float(input("hauteur?"))
print("V=",V(r,h))

# %% [markdown]
# 2) Calcul du périmètre P d'un  cercle de rayon.
#     a) Compléter le programme ci_dessous
#     b) Exécuter le programme avec r = 2 (les dimensions sont en cm)

# %%
from math import*
def ...............
    return ..............
.........................
print("P=",..........)

# %% [markdown]
# 3) Calcul de la surface de l'aire d'un disque de rayon r
#     a) Compléter le programme ci_dessous
#     b) Exécuter le programme avec r = 2 (les dimensions sont en cm)

# %%
from math import*
def ...............
    return ..............
.........................
print("A=",..........)
