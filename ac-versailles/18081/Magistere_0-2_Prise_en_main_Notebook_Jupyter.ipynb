# %% [markdown]
# <h1 class="alert alert-info"><center>Activité : prise en main d'un Notebook Jupyter</center></h1>

# %% [markdown]
# Cette activité a pour objectif de vous faire rapidement explorer les **fonctionnalités de base** de l'interpréteur interactif **jupyter** en mode **Notebook**.

# %% [markdown]
# <h2 class="alert alert-info">Exercice 1 : édition et exécution d'une cellule de code</h2>

# %% [markdown]
# Un notebook jupyter consiste en **cellules** individuelles pouvant contenir du **code** Python, du **texte** (avec formatage Markdown, HTML et LaTeX) ou des **graphiques**. Commençons par les cellules de type Code.
#
# 1. Placez le curseur dans la 1ère cellule <code>Entrée[ ]:</code> ci-dessous puis frappez `<enter>`. Que se passe-t-il ? Rien d'autre que l'insertion d'un saut de ligne... C'est normal, car dans une cellule de type "Code" (c'est-à-dire préfixée par <code>Entrée[ ]:</code>) on est par défaut en mode **édition de code** Python !
#
#
# Pour **exécuter le code** Python d'une cellule, il faut en effet frapper `<maj-entrée>` (ou cliquer sur le bouton <button class='fa fa-step-forward icon-step-forward'></button>, ou encore utiliser le menu `Cellule > Exécuter les cellules et sélectionner la suivante`). Essayez !

# %%
15 + 24

# %%
'Hello tout le monde !'

# %% [markdown]
# Une ligne <code>Sortie[ ]:</code> devrait être apparue en dessous de la 1ère expression, affichant le résultat de celle-ci ! Le curseur est alors automatiquement passé dans la cellule d'en-dessous que vous pouvez exécuter à son tour.
#
# _Notez qu'il est aussi possible de frapper `<ctrl-entrée>` (identique à `Cellule > Exécuter les cellules `). Dans ce cas, le curseur **reste dans la cellule** après l'exécution du code._

# %% [markdown]
# 2. Exécutez maintenant le code de la cellule ci-dessous.

# %%
a = 6     # affectation de la valeur 6 à la variable a
b = 10    # affectation de la valeur 10 à la variable b

print('La somme de ces 2 nombres vaut :', a + b)

# %% [markdown]
# Remarquez que l'exécution du code ci-dessus n'a retourné aucune valeur. Il n'y a pas de prompt <code>Sortie[ ]</code>, uniquement l'affichage d'un texte.

# %% [markdown]
# 3. Peut-on **modifier le code** d'une cellule puis le **ré-exécuter** ? Bien sûr !
# Expérimentez cela dans la cellule ci-dessus en modifiant la valeur des variables <code>a</code> et <code>b</code>, puis frappez à nouveau `<maj-entrée>`

# %% [markdown]
# <h2 class="alert alert-info">Exercice 2 : création de cellules de code</h2>

# %% [markdown]
# Comment puis-je créer **mes propres cellules** de code ? Tout simplement de la façon suivante :
#
# <ul><li>sélectionnez d'abord la cellule juste au-dessus (resp. juste en dessous) de l'emplacement où vous désirez insérer votre propre cellule</li>
# <li>cliquez sur le bouton <button class='fa fa-plus icon-plus btn btn-xs btn-default'></button> ou faites <code>Insérer > Insérer une cellule après</code> (resp. <code>Insérer > Insérer une cellule avant</code>)</li></ul>

# %% [markdown]
# 1. Exercez-vous en créant, juste en-dessous de la présente cellule, une nouvelle cellule.

# %% [markdown]
# 2. Insérez-y le code <code>print('Waouh... ma première cellule !')</code>, puis exécutez le.

# %% [markdown]
# <h2 class="alert alert-info">Exercice 3 : création de cellules de texte</h2>

# %% [markdown]
# Il existe 2 types de cellules de texte, selon le choix effectué à l'aide du menu déroulant de droite ou avec `Cellule > Type de cellule >...` :
# - **Texte Brut** : cellules de texte sans aucun formatage, directement éditables sans devoir _double-cliquer_ dedans ;
# - **Markdown** : cellules dans lesquelles le texte est soumis à un formatage selon la syntaxe Markdown ; les éventuelles balises HTML et le code LaTeX sont également interprétés...

# %% [markdown]
# 1. Créez juste ci-dessous une cellule de type **Texte Brut** . Pour cela, créez une cellule par le procédé standard (elle sera donc de type Code), puis changez son type à l'aide du menu déroulant. Constatez que la cellule reste toujours en mode édition.

# %% [markdown]
# 2. _S'agissant des cellules de texte au format **Markdown**, cela suppose quelques notions relatives au langage de balisage Markdown que l'on peut trouver, par exemple, en suivant le lien [Rédigez en Markdown !](https://www.markdowntutorial.com/fr/). Pour vous donner une idée de la simplicité du balisage Markdown, vous pouvez double-cliquer dans les cellules de texte du présent notebook qui sont toutes au format Markdown._
# <br>
# Saisir un texte en Markdown dans la cellule que vous avez créée ci-dessus. Vous pouvez aussi y ajouter des balises HTML et/ou du code LaTeX si vous les connaissez.

# %% [markdown]
# **Pour plus d'informations : [un Notebook assez complet sur les cellules au format Markdown](http://nbviewer.jupyter.org/github/twistedhardware/mltutorial/blob/master/notebooks/jupyter/2.%20Markdown%20%26%20LaTeX.ipynb)**

# %% [markdown]
# <h2 class="alert alert-info">Exercice 4 : destruction de cellules</h2>

# %% [markdown]
# Pour détruire une cellule, que ce soit du code ou du texte, sélectionnez-la puis cliquez sur le bouton <button class='fa fa-cut icon-cut btn  btn-xs btn-default'></button> (ou faites `Edition > Supprimer les cellules`). Exercez-vous en détruisant les deux cellules ci-dessous. Puis rétablissez-les avec `Edition > Annuler la suppression des cellules`

# %%
# Une cellule de code à jeter !!!

# %% [markdown]
# Une cellule de texte à jeter

# %% [markdown]
# Notez qu'il existe également : le bouton <button class='fa fa-copy icon-copy btn  btn-xs btn-default'></button> (correspondant au menu `Edition > Copier les cellules`) ainsi que le bouton <button class='fa fa-paste icon-paste btn  btn-xs btn-default'></button> (correspondant au menu `Edition > Coller les cellules`)

# %% [markdown]
# <h2 class="alert alert-info">Exercice 5 : sauvegarder et charger un notebook</h2>

# %% [markdown]
# 1. Lorsque vous avez terminé de travailler dans un notebook, **n'oubliez pas de le sauvegarder** avec le bouton <button class='fa fa-save icon-save btn  btn-xs btn-default'></button> (ou le menu `Fichier > Enregistrer sous...`).

# %% [markdown]
# 2. Vous pouvez charger un notebook  le menu `Fichier > Enregistrer sous...`).

# %% [markdown]
# <h2 class="alert alert-info">Exercice 6 : une première utilisation d'un notebook comme calculatrice</h2>

# %% [markdown]
# 1. Exécuter les cellules suivantes et interpréter les différents symboles opératoires qui apparaissent.

# %%
2 + 3

# %%
4 + (-5)

# %%
3 - 4

# %%
17 - 12

# %%
8 * 6

# %%
5 * (-3)

# %%
(2 + 6) * 3

# %%
2 ** 4

# %%
(-2) ** 4

# %%
-2 ** 4

# %%
(3 - 4) ** 4

# %%
4 / 2

# %%
5 / 2

# %%
4 // 2

# %%
5 // 2

# %%
4 % 2

# %%
5 % 2

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <details>
# <summary style="border:2pt solid darkgreen; border-radius:5pt; width:15%; color:white; padding:3px; background-color: #99CC66"> Solution </summary>
#
# <div style="border:1pt solid darkgreen; border-radius:5pt; color:darkgreen; padding:3px; background-color: #99CC66">
#
# Les symboles opératoires <code>+</code>, <code>-</code>, <code>*</code>, <code>/</code> et <code>**</code> correspondent respectivement à l'addition, la soustraction, la multiplication, la division et la puissance.
#
# Les symboles opératoires <code>//</code> et <code>%</code> correspondent respectivement au quotient et au reste dans la division euclidienne.
#
# Les ordres de priorité sont connus.
#
# </div>
# </details>

# %% [markdown]
# 2. En plus de maîtriser les règles opératoires classiques, Python possède de nombreuses fonctions mathématiques. Exécuter les cellules suivantes et déterminer ce que font les différentes fonctions mathématiques proposées.

# %%
from math import *       # importation d'une bibliothèque : on comprendra plus tard ...

# %%
abs(8)

# %%
abs(-8)

# %%
round(1/8,0)

# %%
round(1/8,1)

# %%
round(1/8,2)

# %%
floor(1.25)

# %%
floor(5)

# %%
floor(-3.2)

# %%
sqrt(1)

# %%
sqrt(2)

# %%
sqrt(3)

# %%
exp(1)

# %%
log(1)

# %%
log(exp(1))

# %%
log(10)

# %% [markdown]
# <p style="font-style:italic; color:gray;">Ecrire la réponse ici</p>

# %% [markdown]
# <details>
# <summary style="border:2pt solid darkgreen; border-radius:5pt; width:15%; color:white; padding:3px; background-color: #99CC66"> Solution </summary>
#
# <div style="border:1pt solid darkgreen; border-radius:5pt; color:darkgreen; padding:3px; background-color: #99CC66">
#
# La fonction <code>abs</code> est la fonction valeur absolue.
#
# La fonction <code>round</code> est la fonction valeur approchée.
#
# La fonction <code>floor</code> est la fonction partie entière (inférieure).
#
# La fonction <code>sqrt</code> est la fonction racine carrée.
#
# La fonction <code>exp</code> est la fonction exponentielle.
#
# La fonction <code>log</code> est la fonction logarithme népérien.
#
# Remarque : les bibliothèques seront abordées plus précisément dans la partie I-2 du parcours.
# </div>
# </details>

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Licence Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />Ce document  est mis à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licence Creative Commons Attribution -  Partage dans les Mêmes Conditions 4.0 International</a>.
# Pour toute question : <a href="mailto:charles.poulmaire@ac-versailles.fr">charles.poulmaire@ac-versaillesfr</a>
