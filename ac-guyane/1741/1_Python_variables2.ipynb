# %% [markdown]
# ># Les variables

# %% [markdown]
# >Une **variable** est une donnée stockée dans la mémoire de l'ordinateur. On peut considérer la mémoire de l'ordinateur comme une grande commode , ou chaque tiroir contient une information. Pour retrouver cette information il faut poser une "*etiquette*" sur le tiroir, cette étiquette est le nom de la variable.
# L'**affectation  consiste à **donner une valeur à la variable**, en Python cela s'effectue avec le **symbole "=".**

# %%
mon_age=25.5        #La valeur 25 est AFFECTEE à la variable mon_age (mon_age RECOIT la valeur 25)
print(mon_age)      #Affiche la valeur de la variable
print(mon_age+4)
print(mon_age*2)
type(mon_age)       #Affiche la classe de la variable

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

# %%
#AFFECTATION DE VARIABLES
a=5
b=3
c=a*b
print(a,b,c)

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

# %%
#AFFECTATION MULTIPLE DE VARIABLES
appt,rue="104","Lotissement St Johns"           #On peut affecter plusieurs variables en même temps l'ordre de déclaration doit être le même que l'affectation
codep,ville = 97351,"MATOURY"
print(appt,rue)
print(codep,ville)

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

# %%
texte="Bonjour les amis !"    #Une chaine de caractères est définie entre des doubles apostrophes "".
print(texte)
type(texte)

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

# %% [markdown]
# ># Les types de variables:

# %% [markdown]
# >**Le type de variable** identifie la nature de son contenu : nombre entier texte ect..
# Selon le type de la variable, certaines opérations seront possibles ou non. Par exemple, il existe une méthode pour mesurer la longueur d'une chaine de caractères, mais cette methode sera inefficace sur un nombre décimal.
# Le type d'une variable est définie automatiquement selon le contenu qui lui est affecté c'est ce qu'on appelle le **typage dynamique**.
# Voici les principaux types de variables mentionnés dans les programmes de BCP :
#
# <table align="center">
#   <tr>
#     <th align="center"><b>Différentes classes d'objets</th>
#     <th align="center"><b> </th>
#   </tr>
#   <tr>
#     <td align="center"><b><i>int</b></i></td>
#     <td>c'est la classe des <b>nombres entiers</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>float</b></i></td>
#     <td>c'est la classe des <b>nombres décimaux</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>bool</b></i></td>
#     <td>c'est la classe des <b>booléens</b> (Vrai ou Faux, True/False )</td>
#   </tr>
#     <tr>
#     <td align="center"><b><i>str</b></i></td>
#     <td>c'est la classe des <b>chaînes de caractères (texte)</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>list</b></i></td>
#     <td>c'est la classe des <b>listes d'objets</b></td>
#   </tr>
# </table>
# Soit le code suivant:

# %%
gravite = 10
print(gravite)
type(gravite)

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

#A FAIRE : AFFECTE LA VALEUR 9,81 A GRAVITE ET OBSERVER LE RESULTAT

# %% [markdown]
# >**Le type de variable** identifie la nature de son contenu : nombre entier texte ect..
# Selon le type de la variable, certaines opérations seront possibles ou non. Par exemple, il existe une méthode pour mesurer la longueur d'une chaine de caractères, mais cette methode sera inefficace sur un nombre décimal.
# Le type d'une variable est définie automatiquement selon le contenu qui lui est affecté c'est ce qu'on appelle le **typage dynamique**.
# Voici les principaux types de variables mentionnés dans les programmes de BCP :
#
# <table align="center">
#   <tr>
#     <th align="center"><b>Différentes classes d'objets</th>
#     <th align="center"><b> </th>
#   </tr>
#   <tr>
#     <td align="center"><b><i>int</b></i></td>
#     <td>c'est la classe des <b>nombres entiers</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>float</b></i></td>
#     <td>c'est la classe des <b>nombres décimaux</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>bool</b></i></td>
#     <td>c'est la classe des <b>booléens</b> (Vrai ou Faux, True/False )</td>
#   </tr>
#     <tr>
#     <td align="center"><b><i>str</b></i></td>
#     <td>c'est la classe des <b>chaînes de caractères (texte)</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>list</b></i></td>
#     <td>c'est la classe des <b>listes d'objets</b></td>
#   </tr>
# </table>
# Soit le code suivant:

# %%
gravite = 10
print(gravite)
type(gravite)

#A FAIRE: EXECUTER LE SCRIPT POUR VOIR LES RESULTATS

#A FAIRE : AFFECTE LA VALEUR 9,81 A GRAVITE ET OBSERVER LE RESULTAT

# %% [markdown]
# ># Opérations sur les variables:

# %% [markdown]
# >Les opérations utilisables sur les entiers sont:
#
# <table align="center">
#   <tr>
#     <th align="center"><b>Différentes opérations sur les variables</th>
#     <th align="center"><b> </th>
#   </tr>
#   <tr>
#     <td align="center"><b><i>+</b></i></td>
#     <td>pour l'<b>addition</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>-</b></i></td>
#     <td>pour la <b>soustraction</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>*</b></i></td>
#     <td>pour la <b>multiplication</b> </td>
#   </tr>
#     <tr>
#     <td align="center"><b><i>//</b></i></td>
#     <td>pour le <b>quotient de la division euclidienne</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>%</b></i></td>
#     <td>pour le <b>reste de la division euclydienne</b></td>
#   </tr>
#   <tr>
#     <td align="center"><b><i>**</b></i></td>
#     <td>pour les <b>puissances</b></td>
#   </tr>
# </table>
#
# Voici quelques expmples d'opérations sur les entiers (int) et le flottants (float) :

# %%
7 // 2
# Out:
# 3

# %%
7 % 2
# Out:
# 1

# %%
2 ** 2
# Out:
# 4

# %%
2.1 + 3.5
# Out:
# 5.6

# %%
1.2 * 7.1
# Out:
# 8.52

# %% [markdown]
# ># Exercices d'applications

# %% [markdown]
# >### 1- Utilisation des variables

# %% [markdown]
# 1. Créez une variable **nom** et assignez-lui votre **nom** en tant que valeur.
#
# 2. Créez une variable **date_naissance** et assignez-lui votre date de naissance en tant que valeur.
#
# 3. Créez une variable **taille** et assignez-lui votre taille en tant que valeur (en mètres).
#
# 4. Affichez une phrase qui utilise les variables **nom**, **date_naissance** et **taille** pour dire quelque chose comme : Bonjour, [votre nom] vous mesurez [votre taille] mètres et vous avez ou aurez [votre age] cette année.

# %%
#Ecrivez ici votre script

# %% [markdown]
# >### 2- Opérations sur les variables

# %% [markdown]
# 1. Créez deux variables a et b et assignez-leur les valeurs 10 et 5 respectivement.
#
# 2. Calculez la somme de a et b et stockez-le dans une variable somme.
#
# 3. Calculez la différence entre a et b et stockez-le dans une variable difference.
#
# 4. Calculez le produit de a et b et stockez-le dans une variable produit.
#
# 5. Calculez le quotient de a divisé par b et stockez-le dans une variable quotient.
#
# 6. Calculez le reste de a divisé par b et stockez-le dans une variable reste.
#
# 7. Affichez les valeurs de somme, difference, produit, quotient et reste.

# %%
#Ecrivez votre script ici
