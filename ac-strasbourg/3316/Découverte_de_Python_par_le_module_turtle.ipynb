# %% [markdown]
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/12-13/14-50-38/scratch_carre_sans_boucle.png" style="float: right;">
#
# <h1 style="color:#DDEE00;"> Découverte de Python par le module turtle </h1>
#
# <br><br><br><br><br><br><br><br><br><br><br><br><br><br>
#
# Voici un bloc <mark style="color=DDEEFF; font-family: Consolas;">carre</mark> écrit en langage Scratch.
# <br><br>
# <strong>1. Que réalise cette fonction ?</strong>

# %% [raw]
# Répondre ici :

# %% [markdown]
# <strong>2. La fonction Python <mark style="color=DDEEFF; font-family: Consolas;">carre</mark> écrite ci-dessous réalise la même tâche. Exécuter cette cellule pour mettre la fonction en mémoire.</strong>

# %%
from turtle import*  #import du module turtle

def carre(n):
    "fonction qui trace un carré de côté n"
    forward(n)
    left(90)
    forward(n)
    left(90)
    forward(n)
    left(90)
    forward(n)
    left(90)

# %% [markdown]
# <strong>3. Voici ci-contre le script principal qui appelle le bloc fonction <mark style="color=DDEEFF; font-family: Consolas;">carre</mark> en langage Scratch, et ci-dessous l'équivalent en langage Python.<br>
# Exécuter cette cellule.</strong>
#
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/12-13/14-55-28/scratch_carre_sans_boucle_appel.png" style="float: right;">

# %%
carre(200) # appel de la fonction
done()     # affichage

# %% [markdown]
# <strong>4. Écrire une fonction Python <mark style="color=DDEEFF; font-family: Consolas;">triangle</mark> qui permet de tracer un triangle équilatéral de côté <mark style="color=DDEEFF; font-family: Consolas;">n</mark> et tester la fonction.

# %%
# Écrire ici la fonction Python triangle

# %%
# Écrire ici un appel à la fonction triangle

# %% [markdown]
# <strong>5. Voici un bloc équivalent au bloc <mark style="color=DDEEFF; font-family: Consolas;">carre</mark> optimisé à l'aide d'une boucle, et voici ci-dessous son équivalent en langage Python.<br> Tester cette nouvelle fonction <mark style="color=DDEEFF; font-family: Consolas;">carre</mark>. </strong>
#
# <img src="https://capytale2.ac-paris.fr/web/sites/default/files/2022/12-13/15-18-13/scratch_carre_avec_boucle.png" style="float: right;">

# %%
from turtle import*  #import du module turtle

def carre(n):
    "fonction qui trace un carré de côté n"
    for _ in range(4):
        forward(n)
        left(90)

# %%
# Écrire ici un appel à la fonction carre

# %% [markdown]
# <strong>6. De la même façon, optimiser votre fonction Python <mark style="color=DDEEFF; font-family: Consolas;">triangle</mark> et tester. </strong>

# %%
# Écrire ici la fonction Python triangle

# %%
# Écrire ici un appel à la fonction triangle
