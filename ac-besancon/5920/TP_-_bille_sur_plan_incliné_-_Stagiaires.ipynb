# %% [markdown]
# <div class="alert alert-success" style="border-left: 15px solid #3c763d;">
#     <b>Principe d'un notebook comme celui-ci :</b>
#     <ul>
#     <li>Les cellules de code sont toutes à exécuter, soit avec le bouton en haut, soit avec ctrl+entrée ou maj+entrée.</li>
#     <li>Vous pouvez aussi éditer les textes (comme celui-ci) si vous en avez envie, ajouter des cellules, etc.</li>
#     <li>Pensez à enregistrer pour pouvoir retrouver votre travail.</li>
# </ul>
# </div>
#
# <br>
#
# <h1>TP - Rail incliné</h1>

# %% [markdown]
# <h2>Mesure 1 - Durée de chute</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# durées chronométrées, s :
t = np.array([............])

tmoy = np.mean(t)   # moyenne
tstd = np.std(t)    # écart-type
N = len(t)          # nombre de mesures

print("nb mesures : ", N)
print("moyenne : ", tmoy, "s")
print("écart-type : ", tstd, "s")


# tracé de l'histogramme
plt.figure()
plt.hist(t, label='durée de chute')
plt.xlabel('(secondes)')
plt.ylabel("nombre d'occurrences")
plt.legend()
plt.show()

# %% [markdown]
# <h1> BILAN collectif n°1</h1>

# %% [markdown]
# <b>Suite après bilan :</b>
#
# <h2>Mesure 2 - Longueur du rail</h2>
#
# $L = $ distance à parcourir.
#
# Mesure <b>unique</b> (la répéter ne donne aucune variabilité).
#
# $\Rightarrow$ <b>Estimation de type B</b> (prgm 1ère).
# <ul>
#     <li>Précision $\Delta$ de l'instrument ou du protocole<br>
#         (on est presque certain que le résultat est entre $L-\Delta$ et $L+\Delta$).
#     <li>Incertitude-type $u(L) = \dfrac{\Delta(L)}{\sqrt{3}}$</li>
# </ul>

# %%
L =        # longueur à parcourir, m

DeltaL =      # précision sur L
uL = DeltaL/sqrt(3)

# %% [markdown]
# <h2>Mesure 3 - Angle d'inclinaison</h2>
#
# <b>1/ Mesure.</b>
# <ul>
# <li>Méthode géométrique : $\alpha = \arctan(h/l)$.</li>
# </ul>

# %%
# avec mesures géométriques
alpha = atan(   /   )

print("géométrie : ", round(alpha*180/pi,2), "°")

# %% [markdown]
# <li>Avec le capteur du téléphone (téléphone dans un sens, dans l'autre, moyenne).</li>

# %%
# avec le téléphone (idée : mettre le téléphone dans un sens, dans l'autre, prendre la moyenne)
alpha_tel  =  * pi/180   #exprimé en radian pour le calcul de g
alpha_tel2 =  * pi/180

print("téléphone sens 1 : ", round(alpha_tel*180/pi,2), "°")
print("téléphone sens 2 : ", round(alpha_tel2*180/pi,2), "°")
print("moyenne : ", round(0.5*(alpha_tel2+alpha_tel)*180/pi,2), "°")

# %% [markdown]
# <b>2/ Incertitude </b>
#
# Précision $\Delta(\alpha)$ à discuter (plage de valeurs dans laquelle $\alpha$ se trouve raisonnablement).
#
# Puis $u(\alpha) = \dfrac{\Delta(\alpha)}{\sqrt{3}}$.

# %%
# valeur de alpha finalement retenue :
alpha =  * pi/180  

# et sa précision à estimer :
Delta_alpha =   * pi/180
ualpha =

# %% [markdown]
# <h1> BILAN collectif n°2</h1>
#
# <b>Suite après bilan :</b>
#
# <h2>4 - Calcul de $g$</h2>
#
# <b>1/ Calcul</b>
#
# $g = \dfrac{14\cdot L}{5\cdot \sin(\alpha)\cdot t^2}$

# %%
g = 

print("g = ", round(g,2), "m/s^2")

# %% [markdown]
# <b>2/ Incertitude</b>
#
# C'est une grandeur calculée.
#
# Deux méthodes (au pgrm de term) :
# <ul>
#     <li>Méthode 1 : formule : si $\alpha\ll1$rad, on a
#     $$u(g) = g \cdot \sqrt{\left(\dfrac{u(\alpha)}{\alpha}\right)^2 + \left(\dfrac{2\cdot u(\bar{t})}{\bar{t}}\right)^2 + \left(\dfrac{u(L)}{L}\right)^2}$$
#     <br>&nbsp;</li>
# </ul>

# %%
# calcul de u(g), méthode 1

# %% [markdown]
# <h1> BILAN collectif n°3</h1>
#
# <b>Suite après bilan :</b>
#
# <ul>
#     <li>Méthode 2 : tirages aléatoires.</li>
# </ul>

# %%
# calcul de u(g), méthode 2

# ci-dessous un exemple de rédaction :

liste_g = []
for i in range(10000):
    # tirage aléatoire de alpha, t, L, autour des valeurs mesurées :
    #syntaxe générale : X=np.random.normal(X,u(x))
    alphai = 
    ti = 
    Li = 
    
    # calcul de gi :
    gi = 14*Li/(5*np.sin(alphai)*ti**2)
    liste_g.append(gi)

ug_tirage = 
print("tirages distrib normale : u(g) = ", round(ug_tirage2,2), "m/s^2")


# vous pouvez tester en changeant la distribution,
# avec une syntaxe du type X = np.random.uniform(X-u(X)*sqrt(3), X+u(X)*sqrt(3))

# %% [markdown]
# <b>3/ Comparaison</b> (pgrm term)
#
# $g_\text{réf}=9,8\,\mathrm{m/s^2}$, écart normalisé $z = \dfrac{|g_\text{mes}-g_\text{ref}|}{u(g_\text{mes})}$.

# %%
# calcul de z

# %% [markdown]
# <h1> BILAN collectif n°4</h1>
