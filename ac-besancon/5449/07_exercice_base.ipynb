# %% [markdown]
# ## Exercice 1 : Divisibilité par 2, 3 et 5
# Le but de l'exercice est de créer un programme qui demande un nombre puis indique si ce nombre est divisible par les nombres entiers de 2, 3 ou 5.

# %% [markdown]
# L'opérateur `%` fournit le reste entier d'une division (Dans l'exemple ci-dessous le résultat de l'opération `23%5` est `3`.)

# %%
nombre = 23
nombre%5
# Out:
# 3

# %% [markdown]
# Le programme suivant permettant de d'affirmer si le nombre entré par l'utilisateur est divisible par 2.

# %%
nombre=int(input("Quel est votre nombre ? "))
if (nombre%2==0):
  print(nombre," est divisible par 2")

# %% [markdown]
# ### Travail à réaliser
# 1.   Compléter l'insturction `if` ci-dessus pour qu'il informe l'utilisateur lorsque le nombre n'est divisible par 2. (utiliser l'instruction `else` )
# 2.   Terminer le programme pour qu'il précise si le nombre entré est divisible ou non par 3 et 5.

# %% [markdown]
# ## Exercice 2 : le toit conique (question 3. et 4.)

# %% [markdown]
# *L'énoncé est donné dans sa totalité, mais le but visé est de répondre à l'aide d'un programme python aux questions 3. et 4.*

# %% [markdown]
# ![fonction_toit_conique.png](data:image/png;base64,...)

# %% [markdown]
# Les réponses aux questions 1. et 2. permettent d'établir que la suite étudiée est arithmétique.
#
# Son premier terme est 213 et sa raison vaut -6.

# %% [markdown]
# 1.  Remplacer les `?` dans la fonction `ardoise` afin de rendre celle-ci fonctionnelle et correcte.

# %%
# la fonction ardoise permet de calculer en fonction du rang le nombre d'ardoises nécessaire 
def ardoise(rang):
    return(?+?*(rang-1))

# Cette boucle permet d'afficher le terme de rang n ainsi que sa valeur 
for n in range(1,5):
    print("Terme",n,":",ardoise(n))

# %% [markdown]
# 2.  Modifier les valeurs contenues dans l'instruction `range` afin de pouvoir répondre aux questions 3. et 4. de l'exercice.
