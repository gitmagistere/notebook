# %% [markdown]
# # Activité n°1 : Afficher la date

# %% [markdown]
# 1) Modifier le programme ci-dessous pour que la date du jour s'affiche

# %%
nom_jour = "mardi"
jour = 15
mois = "juin"
print("Aujourd'hui, nous sommes le " + nom_jour+" "+ jour + " " + mois)

# %% [markdown]
# 2) Compléter le programme pour qu'il la date de demain s'affiche

# %%
jour = 15
mois = "juin"
print("Demain, nous serons le "+ ... + " " + mois)
