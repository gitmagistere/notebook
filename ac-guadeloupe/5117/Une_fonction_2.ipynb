# %% [markdown]
#     • Choisir un nombre
#     • L'élever au carré.
#     • Multiplier le résultat par 2.
#     • Retrancher 6 fois le nombre choisi au résultat.
#     • Ajouter 4 à l'ensemble.
#     • Afficher le résultat.

# %%
x=0
x=float(input("Entrez une valeur "))
y=...
print("Le résultat est",y)
