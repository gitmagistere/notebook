# %% [markdown]
#     • Choisir un nombre
#     • L'élever au carré.
#     • Multiplier le résultat par 2.
#     • Retrancher 9 fois le nombre choisi au résultat.
#     • Ajouter 15 à l'ensemble.
#     • Afficher le résultat.

# %% [markdown]
# Corriger le programme suivant afin qu'il correspond à l'algorithme ci-dessus

# %%
x=0
x=float(input("Entrez une valeur "))
y=9x+15
print("Le résultat est",y)

# %% [markdown]
# Executer le programme suivant avec (-5;90) , (6;232) et(3;52) afin de déterminer les couples qui appartiennent à la courbe.

# %%
x=float(input("Saisir x "))
y=float(input("Saisir y "))
if y==5*x**2+9*x-2:
    print("le couple (x;y) appartient à la courbe")
else:
    print("le couple (x;y) n'appartient pas à la courbe")
