# %%
#
# Algorithme des crêpes en python3
#

oeufs = 12       #nombre
lait = 1.0       #en litre
beurre = 500    #en grammes
sucre = 1000    #en grammes
farine = 500   #en grammes

PasCrepes = "Pas de crêpes aujourd'hui..."
OuiCrepes = "Sortir les ustensiles et se mettre au boulot"
OuiQuandMeme = "Pas grave on peut faire sans, opération crêpes maintenue"

if oeufs > 0 :
    if lait > 0 :
        if farine > 0 :
            if sucre > 0 :
                if beurre > 0 :
                    print(OuiCrepes)
                else :
                    print(OuiQuandMeme)
                    print(OuiCrepes)
            else :
                print(OuiQuandMeme)
                if beurre > 0 :
                    print(OuiCrepes)
                else :
                    print(OuiQuandMeme)
                    print(OuiCrepes)
        else :
            print(PasCrepes)
    else :
        print(PasCrepes)
else :
    print(PasCrepes)
# Out:
# Sortir les ustensiles et se mettre au boulot
